# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install geoviews geopandas requests
# Out:
# Requirement already satisfied: geoviews in d:\anaconda\lib\site-packages (1.13.0)
# Requirement already satisfied: geopandas in d:\anaconda\lib\site-packages (1.0.1)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (2.32.2)
# Requirement already satisfied: bokeh<3.6.0,>=3.5.0 in d:\anaconda\lib\site-packages (from geoviews) (3.5.2)
# Requirement already satisfied: cartopy>=0.18.0 in d:\anaconda\lib\site-packages (from geoviews) (0.24.1)
# Requirement already satisfied: holoviews>=1.16.0 in d:\anaconda\lib\site-packages (from geoviews) (1.19.0)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from geoviews) (1.26.4)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from geoviews) (23.2)
# Requirement already satisfied: panel>=1.0.0 in d:\anaconda\lib\site-packages (from geoviews) (1.5.3)
# Requirement already satisfied: param in d:\anaconda\lib\site-packages (from geoviews) (2.1.0)
# Requirement already satisfied: pyproj in d:\anaconda\lib\site-packages (from geoviews) (3.7.0)
# Requirement already satisfied: shapely in d:\anaconda\lib\site-packages (from geoviews) (2.0.6)
# Requirement already satisfied: xyzservices in d:\anaconda\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: pyogrio>=0.7.2 in d:\anaconda\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: pandas>=1.4.0 in d:\anaconda\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: Jinja2>=2.9 in d:\anaconda\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in d:\anaconda\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (1.2.0)
# Requirement already satisfied: pillow>=7.1.0 in d:\anaconda\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in d:\anaconda\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in d:\anaconda\lib\site-packages (from bokeh<3.6.0,>=3.5.0->geoviews) (6.4.1)
# Requirement already satisfied: matplotlib>=3.6 in d:\anaconda\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.8.4)
# Requirement already satisfied: pyshp>=2.3 in d:\anaconda\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in d:\anaconda\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in d:\anaconda\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: bleach in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: linkify-it-py in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: markdown in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (4.66.4)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from Jinja2>=2.9->bokeh<3.6.0,>=3.5.0->geoviews) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# Requirement already satisfied: webencodings in d:\anaconda\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in d:\anaconda\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->panel>=1.0.0->geoviews) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing Dependencies and Setup
import hvplot.pandas
import pandas as pd
import geoviews as gv
import requests
from bokeh.io import show
from bokeh.plotting import figure

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b197cbb1-af5b-41c9-bf45-f5796d36b67a" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"ce7062c1-7fac-4320-bad8-6934ec01f366":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"5e6e1f4c8425449eb42952babd15c5b4","client_comm_id":"83a79ba823c04c62997ac67aa05088e3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"ce7062c1-7fac-4320-bad8-6934ec01f366","roots":{"p1002":"b197cbb1-af5b-41c9-bf45-f5796d36b67a"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Loading the CSV file created in the Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Displaying sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  blackmans bay -43.0167  147.3167     60.53        60           1
# 1        1        stanley  54.8680   -1.6985     45.18        89           0
# 2        2          tiksi  71.6872  128.8694     -0.51        99          86
# 3        3     queenstown -31.8976   26.8753     54.81        92         100
# 4        4     concepcion -36.8270  -73.0498     58.80        67          40
#
#    Wind Speed Country        Date
# 0        1.01      AU  1731280921
# 1       10.36      GB  1731280922
# 2        3.00      RU  1731280923
# 3        4.27      ZA  1731280924
# 4       10.36      CL  1731280918

# %%
#Printing Columns to check their spelling and avoid any mispelling errors in code when calling the variables
print(city_data_df.columns)
# Out:
# Index(['City_ID', 'City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    size="Humidity",
    scale=1,
    color="City",
    tiles="OSM",
    frame_width=700,
    frame_height=500
)
 
# Displaying the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrowing down cities that fit criteria and drop any results with null values
filtered_cities = city_data_df[(city_data_df['Humidity'] > 50) & (city_data_df['Max Temp'] < 30)]

# Droping any rows with null values
filtered_cities_cleaned = filtered_cities.dropna()

# Display sample data
filtered_cities_cleaned.head()  # You can also use .sample() to display a random sample
# Out:
#     City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2         2         tiksi  71.6872  128.8694     -0.51        99          86
# 6         6  longyearbyen  78.2186   15.6401     26.44        93          75
# 7         7       aasiaat  68.7098  -52.8699     13.26        99          90
# 11       11       udachny  66.4167  112.4000      3.33        95          94
# 12       12     vorgashor  67.5833   63.9500      3.20        98          84
#
#     Wind Speed Country        Date
# 2         3.00      RU  1731280923
# 6         3.44      SJ  1731280928
# 7         4.88      GL  1731280929
# 11        4.90      RU  1731280744
# 12        8.23      RU  1731280935

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# 
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# 
hotel_df['Hotel Name'] = None  # Initialize with None (or np.nan if you prefer)

# 
hotel_df.head()  # Use .sample() if you prefer a random sample
# Out:
#             City Country      Lat       Lng  Humidity Hotel Name
# 0  blackmans bay      AU -43.0167  147.3167        60       None
# 1        stanley      GB  54.8680   -1.6985        89       None
# 2          tiksi      RU  71.6872  128.8694        99       None
# 3     queenstown      ZA -31.8976   26.8753        92       None
# 4     concepcion      CL -36.8270  -73.0498        67       None

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Setting parameters to search for a hotel
radius = 50000  # Setting a search radius of 50 km

# Creating a params dictionary to hold the Geoapify API key and other filters
params = {
    "categories": "accommodation.hotel",  # Searching for hotels
    "apiKey": geoapify_key,    
    "limit": 1                            # Limitting results to the first 5 hotels found
}

# Printing a message to follow up the hotel search
print("Starting hotel search")

# Iterating through the hotel_df DataFrame
for index, row in hotel_df.iterrows():

    # Getting the city's name
    city = row["City"]
    
    # Getting latitude and longitude from the DataFrame for each city
    latitude = row['Lat']
    longitude = row['Lng']

    # Adding the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"  # Setting filter as circle with coordinates
    params.pop("bias", None)  # Remove bias for now, just to test

    # Setting base URL for the Geoapify API
    base_url = "https://api.geoapify.com/v2/places"

    # Making an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Converting the API response to JSON format
    name_address = response.json()

    # Debugging: Print API response status and content
    print(f"Response for {city}: Status {response.status_code}")
    print(name_address)

    # Grabbing the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        features = name_address.get("features", [])
        if features:
            hotel_df.loc[index, "Hotel Name"] = features[0]["properties"]["name"]
        else:
            hotel_df.loc[index, "Hotel Name"] = "No hotel found"
    except Exception as e:
        print(f"Error in city {city}: {e}")
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Logging the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Displaying sample data
hotel_df.head()
# Out:
# Starting hotel search
# Response for blackmans bay: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel Grand Chancellor Hobart', 'country': 'Australia', 'country_code': 'au', 'state': 'Tasmania', 'city': 'Hobart', 'municipality': 'City of Hobart', 'postcode': '7000', 'suburb': 'Hobart', 'street': 'Davey Street', 'housenumber': '1', 'lon': 147.33337188844695, 'lat': -42.880809600000006, 'state_code': 'TAS', 'formatted': 'Hotel Grand Chancellor Hobart, 1 Davey Street, Hobart TAS 7000, Australia', 'address_line1': 'Hotel Grand Chancellor Hobart', 'address_line2': '1 Davey Street, Hobart TAS 7000, Australia', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.building', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel Grand Chancellor Hobart', 'phone': '+61 3 6235 4535', 'osm_id': 27501514, 'tourism': 'hotel', 'website': 'https://www.grandchancellorhotels.com/au/hobart', 'building': 'hotel', 'osm_type': 'w', 'wikidata': 'Q12060551', 'addr:city': 'Hobart', 'addr:state': 'TAS', 'addr:street': 'Davey Street', 'addr:suburb': 'Hobart', 'addr:postcode': 7000, 'building:levels': 12, 'addr:housenumber': 1}}, 'website': 'https://www.grandchancellorhotels.com/au/hobart', 'contact': {'phone': '+61 3 6235 4535'}, 'wiki_and_media': {'wikidata': 'Q12060551'}, 'building': {'levels': 12, 'type': 'hotel'}, 'place_id': '5122c985fbaa6a624059b60f775ebe7045c0f00102f901caa3a3010000000092031d486f74656c204772616e64204368616e63656c6c6f7220486f62617274'}, 'geometry': {'type': 'Point', 'coordinates': [147.33337188844695, -42.88080960095924]}}]}
# blackmans bay - nearest hotel: Hotel Grand Chancellor Hobart
# Response for stanley: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hilton Newcastle Gateshead', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'state_district': 'North East', 'county': 'Tyne and Wear', 'city': 'Gateshead', 'postcode': 'NE8 2AR', 'district': 'Ochre Yards', 'street': 'Bottle Bank', 'lon': -1.60647406055147, 'lat': 54.9661058, 'state_code': 'ENG', 'formatted': 'Hilton Newcastle Gateshead, Bottle Bank, Gateshead, NE8 2AR, United Kingdom', 'address_line1': 'Hilton Newcastle Gateshead', 'address_line2': 'Bottle Bank, Gateshead, NE8 2AR, United Kingdom', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'internet_access', 'internet_access.free', 'wheelchair', 'wheelchair.yes'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.facilities', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'fax': '+44-191-490-9800', 'name': 'Hilton Newcastle Gateshead', 'brand': 'Hilton', 'email': 'events.newcastle@hilton.com', 'image': 'https://www.geograph.org.uk/photo/1833169', 'phone': '+44-191-490-9700', 'rooms': 254, 'stars': 4, 'osm_id': 32994527, 'fhrs:id': 339586, 'smoking': 'no', 'tourism': 'hotel', 'website': 'https://www.hilton.com/en/hotels/nclhihi-hilton-newcastle-gateshead/', 'building': 'hotel', 'operator': 'Hilton Hotels', 'osm_type': 'w', 'wikidata': 'Q61567322', 'addr:city': 'Gateshead', 'wheelchair': 'yes', 'addr:county': 'Tyne and Wear', 'addr:street': 'Bottle Bank', 'addr:postcode': 'NE8 2AR', 'brand:wikidata': 'Q598884', 'brand:wikipedia': 'en:Hilton Hotels & Resorts', 'internet_access': 'wlan', 'contact:facebook': 'https://www.facebook.com/HiltonNewcastleGateshead', 'contact:linkedin': 'https://uk.linkedin.com/pub/hilton-gateshead/67/224/2bb', 'contact:instagram': 'https://www.instagram.com/hiltonnewcastlegateshead/', 'internet_access:fee': 'no'}}, 'website': 'https://www.hilton.com/en/hotels/nclhihi-hilton-newcastle-gateshead/', 'brand': 'Hilton', 'brand_details': {'wikidata': 'Q598884', 'wikipedia': 'en:Hilton Hotels & Resorts'}, 'operator': 'Hilton Hotels', 'contact': {'phone': '+44-191-490-9700', 'email': 'events.newcastle@hilton.com', 'fax': '+44-191-490-9800'}, 'facilities': {'internet_access': True, 'wheelchair': True, 'smoking': False}, 'wiki_and_media': {'wikidata': 'Q61567322', 'image': 'https://www.geograph.org.uk/photo/1833169'}, 'accommodation': {'stars': 4, 'rooms': 254}, 'building': {'type': 'hotel'}, 'place_id': '51f20dff241eb4f9bf59be78d65aa97b4b40f00102f901df74f7010000000092031a48696c746f6e204e6577636173746c6520476174657368656164'}, 'geometry': {'type': 'Point', 'coordinates': [-1.606474060551474, 54.96610579941033]}}]}
# stanley - nearest hotel: Hilton Newcastle Gateshead
# Response for tiksi: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Арктика', 'country': 'Russia', 'country_code': 'ru', 'region': 'Far Eastern Federal District', 'state': 'Sakha Republic', 'county': 'Bulunsky Ulus', 'city': 'Tiksi', 'suburb': 'Tiksi-3', 'street': 'Polyarnoi aviatsii street', 'lon': 128.87147940836854, 'lat': 71.6922024, 'formatted': 'Арктика, Polyarnoi aviatsii street, Tiksi-3, Tiksi, Sakha Republic, Russia', 'address_line1': 'Арктика', 'address_line2': 'Polyarnoi aviatsii street, Tiksi-3, Tiksi, Sakha Republic, Russia', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details.accommodation', 'details.building'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Арктика', 'stars': 2, 'osm_id': 141488442, 'tourism': 'hotel', 'building': 'yes', 'osm_type': 'w', 'building:levels': 4}}, 'accommodation': {'stars': 2}, 'building': {'levels': 4}, 'place_id': '5192c2c828e31b60405952c94f0b4dec5140f00102f9013af16e080000000092030ed090d180d0bad182d0b8d0bad0b0'}, 'geometry': {'type': 'Point', 'coordinates': [128.87147940836854, 71.6922024039425]}}]}
# tiksi - nearest hotel: Арктика
# Response for queenstown: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Queens Hotel', 'country': 'South Africa', 'country_code': 'za', 'state': 'Eastern Cape', 'county': 'Chris Hani District Municipality', 'city': 'Lukhanji Local Municipality', 'town': 'Komani', 'postcode': '5319', 'suburb': 'South Bourne', 'street': 'Ebden Street', 'lon': 26.8810973, 'lat': -31.8983005, 'state_code': 'EC', 'formatted': 'Queens Hotel, Ebden Street, South Bourne, Lukhanji Local Municipality, 5319, South Africa', 'address_line1': 'Queens Hotel', 'address_line2': 'Ebden Street, South Bourne, Lukhanji Local Municipality, 5319, South Africa', 'categories': ['accommodation', 'accommodation.hotel'], 'details': [], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Queens Hotel', 'osm_id': 707580194, 'tourism': 'hotel', 'osm_type': 'n'}}, 'place_id': '510918b8978fe13a40590de88205f7e53fc0f00103f90122d12c2a0000000092030c517565656e7320486f74656c'}, 'geometry': {'type': 'Point', 'coordinates': [26.881097299999997, -31.898300499400694]}}]}
# queenstown - nearest hotel: Queens Hotel
# Response for concepcion: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Wyndham Concepción Pettra', 'country': 'Chile', 'country_code': 'cl', 'state': 'Biobio Region', 'county': 'Provincia de Concepción', 'city': 'Hualpén', 'postcode': '4061735', 'street': 'Autopista Concepción - Talcahuano', 'housenumber': '8676', 'lon': -73.07070153939432, 'lat': -36.793018599999996, 'formatted': 'Wyndham Concepción Pettra, Autopista Concepción - Talcahuano 8676, 406 1735 Hualpén, Chile', 'address_line1': 'Wyndham Concepción Pettra', 'address_line2': 'Autopista Concepción - Talcahuano 8676, 406 1735 Hualpén, Chile', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'internet_access', 'internet_access.free'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.facilities', 'details.payment', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Wyndham Concepción Pettra', 'brand': 'Wyndham', 'email': 'centralreservas@hotelespettra.com', 'phone': '+41 316 3000', 'rooms': 127, 'stars': '4S', 'osm_id': 354202045, 'smoking': 'no', 'tourism': 'hotel', 'website': 'https://www.hotelespettra.com', 'building': 'hotel', 'osm_type': 'w', 'wikidata': 'Q111415394', 'addr:city': 'Hualpén', 'addr:street': 'Autopista Concepción - Talcahuano', 'payment:cash': 'yes', 'payment:visa': 'yes', 'official_name': 'Wyndham Hotels & Resorts', 'brand:wikidata': 'Q8040120', 'internet_access': 'yes', 'addr:housenumber': 8676, 'air_conditioning': 'yes', 'payment:mastercard': 'yes', 'internet_access:fee': 'no', 'payment:debit_cards': 'yes', 'payment:credit_cards': 'yes', 'payment:american_express': 'yes'}}, 'website': 'https://www.hotelespettra.com', 'brand': 'Wyndham', 'brand_details': {'wikidata': 'Q8040120'}, 'name_other': {'official_name': 'Wyndham Hotels & Resorts'}, 'contact': {'phone': '+41 316 3000', 'email': 'centralreservas@hotelespettra.com'}, 'facilities': {'internet_access': True, 'smoking': False, 'air_conditioning': True}, 'wiki_and_media': {'wikidata': 'Q111415394'}, 'payment_options': {'cash': True, 'visa': True, 'mastercard': True, 'debit_cards': True, 'credit_cards': True, 'american_express': True}, 'accommodation': {'stars': '4S', 'rooms': 127}, 'building': {'type': 'hotel'}, 'place_id': '516ddebf5f864452c059c0b22ca2816542c0f00102f901bdb11c150000000092031a57796e6468616d20436f6e6365706369c3b36e20506574747261'}, 'geometry': {'type': 'Point', 'coordinates': [-73.0707015393943, -36.79301860029727]}}]}
# concepcion - nearest hotel: Wyndham Concepción Pettra
# Response for saipan: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Mariana Resort and Spa', 'country': 'United States', 'country_code': 'us', 'state': 'Northern Mariana Islands', 'county': 'Saipan Municipality', 'postcode': '96950', 'suburb': 'As Matuis', 'street': 'Chalan Pale Arnold', 'lon': 145.7868245938962, 'lat': 15.264154300000001, 'state_code': 'MP', 'formatted': 'Mariana Resort and Spa, Chalan Pale Arnold, As Matuis, MP 96950, United States of America', 'address_line1': 'Mariana Resort and Spa', 'address_line2': 'Chalan Pale Arnold, As Matuis, MP 96950, United States of America', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Mariana Resort and Spa', 'phone': '+16703220770', 'osm_id': -11940519, 'tourism': 'hotel', 'website': 'https://www.marianaresort.com/', 'osm_type': 'r', 'addr:city': 'Saipan', 'addr:state': 'MP', 'previously': 'node:2465182708', 'addr:street': 'Chalan Pale Arnold', 'addr:postcode': 96950}}, 'website': 'https://www.marianaresort.com/', 'contact': {'phone': '+16703220770'}, 'place_id': '51204fc5aa2d39624059d2aa7e3b3f872e40f00101f901a732b600000000009203164d617269616e61205265736f727420616e6420537061'}, 'geometry': {'type': 'Point', 'coordinates': [145.7868245938962, 15.2641542999385]}}]}
# saipan - nearest hotel: Mariana Resort and Spa
# Response for longyearbyen: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Funken Lodge (formerly Spitsbergen Hotel)', 'country': 'Norway', 'country_code': 'no', 'state': 'Svalbard', 'city': 'Longyearbyen', 'postcode': '9170', 'suburb': 'Nybyen', 'street': 'Vei 210', 'lon': 15.624022070950469, 'lat': 78.21144165, 'formatted': 'Funken Lodge (formerly Spitsbergen Hotel), Vei 210, 9170 Longyearbyen, Norway', 'address_line1': 'Funken Lodge (formerly Spitsbergen Hotel)', 'address_line2': 'Vei 210, 9170 Longyearbyen, Norway', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'internet_access', 'internet_access.free', 'wheelchair', 'wheelchair.yes'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'fax': '+47 79 026201', 'name': 'Funken Lodge (formerly Spitsbergen Hotel)', 'email': 'hotel@spitsbergentravel.no', 'phone': '+47 79 02 62 00', 'rooms': 88, 'osm_id': 387676161, 'tourism': 'hotel', 'website': 'http://www.spitsbergentravel.no', 'building': 'hotel', 'loc_name': 'Funken', 'osm_type': 'w', 'wheelchair': 'yes', 'internet_access': 'wlan', 'internet_access:fee': 'no'}}, 'website': 'http://www.spitsbergentravel.no', 'name_other': {'loc_name': 'Funken'}, 'contact': {'phone': '+47 79 02 62 00', 'email': 'hotel@spitsbergentravel.no', 'fax': '+47 79 026201'}, 'facilities': {'internet_access': True, 'wheelchair': True}, 'accommodation': {'rooms': 88}, 'building': {'type': 'hotel'}, 'place_id': '51ca6d25d27f3f2f4059c8f08e42888d5340f00102f90101781b170000000092032946756e6b656e204c6f6467652028666f726d65726c7920537069747362657267656e20486f74656c29'}, 'geometry': {'type': 'Point', 'coordinates': [15.624022070950463, 78.21144164999998]}}]}
# longyearbyen - nearest hotel: Funken Lodge (formerly Spitsbergen Hotel)
# Response for aasiaat: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'SØMA', 'country': 'Greenland', 'country_code': 'gl', 'state': 'Qeqertalik', 'city': 'Aasiaat', 'postcode': '3950', 'street': 'Katsiaap Aqquserna', 'lon': -52.8797412249141, 'lat': 68.7067777, 'formatted': 'SØMA, Katsiaap Aqquserna, 3950 Aasiaat, Greenland', 'address_line1': 'SØMA', 'address_line2': 'Katsiaap Aqquserna, 3950 Aasiaat, Greenland', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'building.catering', 'internet_access'], 'details': ['details.accommodation', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'SØMA', 'email': 'aasiaat@soemandshjem.gl', 'level': 2, 'phone': '+299892711', 'rooms': 52, 'osm_id': 437469227, 'cuisine': 'fast_food;dagens_ret', 'smoking': 'no', 'tourism': 'hotel', 'building': 'yes', 'osm_type': 'w', 'addr:city': 'Aasiaat', 'addr:street': 'SØMA', 'addr:postcode': 3950, 'internet_access': 'yes', 'internet_access:fee': 'yes'}}, 'contact': {'phone': '+299892711', 'email': 'aasiaat@soemandshjem.gl'}, 'facilities': {'internet_access': True, 'smoking': False}, 'accommodation': {'rooms': 52}, 'place_id': '517bf9465c9b704ac0592ed285d83b2d5140f00102f9012b40131a0000000092030553c3984d41'}, 'geometry': {'type': 'Point', 'coordinates': [-52.879741224914106, 68.70677769726237]}}]}
# aasiaat - nearest hotel: SØMA
# Response for edinburgh of the seven seas: Status 200
# {'type': 'FeatureCollection', 'features': []}
# edinburgh of the seven seas - nearest hotel: No hotel found
# Response for rio claro: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel Mosteiro', 'country': 'Brazil', 'country_code': 'br', 'region': 'Southeast Region', 'state': 'São Paulo', 'county': 'Região Geográfica Intermediária de Bauru', 'city': 'Brotas', 'municipality': 'Região Imediata de Jaú', 'district': 'Brotas', 'street': 'Estrada do Patrimônio', 'housenumber': 'Km 10', 'lon': -48.04163557, 'lat': -22.3986455, 'state_code': 'SP', 'formatted': 'Hotel Mosteiro, Estrada do Patrimônio Km 10, Brotas - SP, Brazil', 'address_line1': 'Hotel Mosteiro', 'address_line2': 'Estrada do Patrimônio Km 10, Brotas - SP, Brazil', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel Mosteiro', 'email': 'fale@hotelmosteiro.com.br', 'phone': '+55 14 3653-1064;+55 14 3014-9199;+55 14 99162-9206;+55 11 4063-5668', 'osm_id': 458796666, 'tourism': 'hotel', 'website': 'http://hotelmosteiro.com.br', 'osm_type': 'w', 'addr:street': 'Estrada do Patrimônio', 'contact:skype': 'hotel.mosteiro', 'opening_hours': '24/7', 'addr:housenumber': 'Km 10', 'contact:facebook': 'https://www.facebook.com/HotelMosteiro/', 'contact:whatsapp': '+55 14 99901-5531'}}, 'website': 'http://hotelmosteiro.com.br', 'opening_hours': '24/7', 'contact': {'phone': '+55 14 3653-1064;+55 14 3014-9199;+55 14 99162-9206;+55 11 4063-5668', 'email': 'fale@hotelmosteiro.com.br'}, 'place_id': '510ac07950540548c0591ad4a9a10d6636c0f00102f9017aae581b0000000092030e486f74656c204d6f73746569726f'}, 'geometry': {'type': 'Point', 'coordinates': [-48.04163557, -22.398645500146905]}}]}
# rio claro - nearest hotel: Hotel Mosteiro
# Response for ke-macina: Status 200
# {'type': 'FeatureCollection', 'features': []}
# ke-macina - nearest hotel: No hotel found
# Response for udachny: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Вилюй', 'country': 'Russia', 'country_code': 'ru', 'region': 'Far Eastern Federal District', 'state': 'Sakha Republic', 'county': 'Mirninsky Ulus', 'city': 'Udachny', 'municipality': 'городское поселение Удачный', 'postcode': '678188', 'suburb': 'Надёжный', 'street': 'Anabar Road', 'lon': 112.3072698, 'lat': 66.4026128, 'formatted': 'Вилюй, Anabar Road, Надёжный, Udachny, Sakha Republic, Russia, 678188', 'address_line1': 'Вилюй', 'address_line2': 'Anabar Road, Надёжный, Udachny, Sakha Republic, Russia, 678188', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Вилюй', 'osm_id': 4700652393, 'name:ru': 'Вилюй', 'tourism': 'hotel', 'osm_type': 'n'}}, 'name_international': {'ru': 'Вилюй'}, 'place_id': '511a83f34eaa135c405990667768c4995040f00103f90169432e180100000092030ad092d0b8d0bbd18ed0b9'}, 'geometry': {'type': 'Point', 'coordinates': [112.3072698, 66.40261279735773]}}]}
# udachny - nearest hotel: Вилюй
# Response for vorgashor: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': '"Мегаполис"', 'country': 'Russia', 'country_code': 'ru', 'region': 'Northwestern Federal District', 'state': 'Komi Republic', 'county': 'Vorkuta Urban Okrug', 'city': 'Vorkuta', 'postcode': '169900', 'street': 'Парковая улица', 'housenumber': '34А', 'lon': 64.0497672, 'lat': 67.4957903, 'formatted': '"Мегаполис", Парковая улица 34А, Vorkuta, Komi Republic, Russia, 169900', 'address_line1': '"Мегаполис"', 'address_line2': 'Парковая улица 34А, Vorkuta, Komi Republic, Russia, 169900', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': '"Мегаполис"', 'osm_id': 4858699874, 'tourism': 'hotel', 'osm_type': 'n', 'contact:phone': '+7-82151-7-35-37'}}, 'contact': {'phone': '+7-82151-7-35-37'}, 'place_id': '51771ac4622f035040598d883907bbdf5040f00103f90162e099210100000092031422d09cd0b5d0b3d0b0d0bfd0bed0bbd0b8d18122'}, 'geometry': {'type': 'Point', 'coordinates': [64.0497672, 67.49579029673096]}}]}
# vorgashor - nearest hotel: "Мегаполис"
# Response for acarau: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Villa Mandi', 'country': 'Brazil', 'country_code': 'br', 'region': 'Northeast Region', 'state': 'Ceará', 'county': 'Região Geográfica Intermediária de Sobral', 'city': 'Jijoca de Jericoacoara', 'municipality': 'Região Geográfica Imediata de Acaraú', 'postcode': '62598-000', 'suburb': 'Vila de Jericoacoara', 'street': 'Rua da Igreja', 'lon': -40.51707822905478, 'lat': -2.79262725, 'state_code': 'CE', 'formatted': 'Villa Mandi, Rua da Igreja, Vila de Jericoacoara, Jijoca de Jericoacoara - CE, 62598-000, Brazil', 'address_line1': 'Villa Mandi', 'address_line2': 'Rua da Igreja, Vila de Jericoacoara, Jijoca de Jericoacoara - CE, 62598-000, Brazil', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.building', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Villa Mandi', 'osm_id': 1028355120, 'tourism': 'hotel', 'website': 'https://www.villamandi.com.br/', 'building': 'hotel', 'osm_type': 'w', 'addr:city': 'Jericoacoara', 'roof:shape': 'gabled', 'addr:street': 'Avenida Beira Mar', 'roof:levels': 1, 'addr:country': 'BR', 'addr:postcode': '62598-000', 'contact:email': 'reservas.villamandi@mandicollection.com.br', 'building:levels': 3}}, 'website': 'https://www.villamandi.com.br/', 'contact': {'email': 'reservas.villamandi@mandicollection.com.br'}, 'building': {'levels': 3, 'type': 'hotel', 'roof': {'shape': 'gabled', 'levels': 1}}, 'place_id': '51c7a1919e2f4244c059b6339df44c5706c0f00102f90130744b3d0000000092030b56696c6c61204d616e6469'}, 'geometry': {'type': 'Point', 'coordinates': [-40.51707822905478, -2.7926272497629396]}}]}
# acarau - nearest hotel: Villa Mandi
# Response for horta: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel do Canal', 'country': 'Portugal', 'country_code': 'pt', 'city': 'Horta', 'postcode': '9900-026', 'district': 'Horta (Angústias)', 'suburb': 'Matriz', 'street': 'Largo Doutor Manuel de Arriaga', 'lon': -28.626799606345706, 'lat': 38.528397350000006, 'formatted': 'Hotel do Canal, Largo Doutor Manuel de Arriaga, 9900-026 Horta, Portugal', 'address_line1': 'Hotel do Canal', 'address_line2': 'Largo Doutor Manuel de Arriaga, 9900-026 Horta, Portugal', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel do Canal', 'email': 'reservas.grupos@bhc.pt', 'phone': '+351 292 202120', 'stars': 4, 'osm_id': -17075236, 'landuse': 'commercial', 'name:pt': 'Hotel do Canal', 'tourism': 'hotel', 'website': 'https://www.bensaudehotels.com/en/hoteldocanal', 'osm_type': 'r', 'wikidata': 'Q111408376', 'addr:city': 'Horta (Angústias)', 'addr:street': 'Largo Dr. Manuel Arriaga', 'addr:country': 'PT', 'addr:postcode': '9900-026', 'name:etymology': 'Canal do Faial', 'name:etymology:wikidata': 'Q5429639', 'name:etymology:wikipedia': 'pt:Canal do Faial'}}, 'website': 'https://www.bensaudehotels.com/en/hoteldocanal', 'name_international': {'pt': 'Hotel do Canal'}, 'contact': {'phone': '+351 292 202120', 'email': 'reservas.grupos@bhc.pt'}, 'wiki_and_media': {'wikidata': 'Q111408376'}, 'accommodation': {'stars': 4}, 'place_id': '51846662f075a03cc05923e53c86a2434340f00101f901248c04010000000092030e486f74656c20646f2043616e616c'}, 'geometry': {'type': 'Point', 'coordinates': [-28.6267996063457, 38.528397350057524]}}]}
# horta - nearest hotel: Hotel do Canal
# Response for 'alaqahdari dishu: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'ftg', 'country': 'Afghanistan', 'country_code': 'af', 'state': 'Helmand Province', 'county': 'Dishu', 'lon': 63.5005703, 'lat': 30.1163109, 'formatted': 'ftg, Dishu, Afghanistan', 'address_line1': 'ftg', 'address_line2': 'Dishu, Afghanistan', 'categories': ['accommodation', 'accommodation.hotel'], 'details': [], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'ftg', 'osm_id': 3649946928, 'tourism': 'hotel', 'osm_type': 'n'}}, 'place_id': '51a9ec05b012c04f4059a781168dc61d3e40f00103f90130c58dd900000000920303667467'}, 'geometry': {'type': 'Point', 'coordinates': [63.5005703, 30.11631089972948]}}]}
# 'alaqahdari dishu - nearest hotel: ftg
# Response for port-aux-francais: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Keravel', 'country': 'France', 'country_code': 'fr', 'state': 'French Southern and Antarctic Lands', 'city': 'Port-aux-Français', 'municipality': 'Kerguelen Archipelago', 'street': 'Chemin de Keravel', 'lon': 70.21991619089022, 'lat': -49.34887615, 'formatted': 'Chemin de Keravel, Port-aux-Français, France', 'address_line1': 'Chemin de Keravel', 'address_line2': 'Port-aux-Français, France', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': [], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Keravel', 'osm_id': 187212461, 'tourism': 'hotel', 'building': 'yes', 'osm_type': 'w', 'addr:city': 'Port-aux-Français', 'addr:street': 'Chemin de Keravel', 'addr:district': 'Îles Kerguelen', 'addr:territoire': 'TAAF'}}, 'place_id': '5100ef5b1b138e51405966c640f9a7ac48c0f00102f901ada2280b000000009203074b65726176656c'}, 'geometry': {'type': 'Point', 'coordinates': [70.21991619089022, -49.34887614882318]}}]}
# port-aux-francais - nearest hotel: Keravel
# Response for hithadhoo: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Pebbles Inn', 'country': 'Maldives', 'country_code': 'mv', 'state': 'Addu Atoll', 'city': 'Hithadhoo', 'postcode': '19020', 'street': "Shabnam hin'gun", 'lon': 73.0865138, 'lat': -0.6002215, 'formatted': "Pebbles Inn, Shabnam hin'gun, Hithadhoo 19020, Maldives", 'address_line1': 'Pebbles Inn', 'address_line2': "Shabnam hin'gun, Hithadhoo 19020, Maldives", 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Pebbles Inn', 'email': 'stay@pebblesinn.com', 'phone': 6880660, 'osm_id': 5156483845, 'tourism': 'hotel', 'website': 'https://www.pebblesinn.com/', 'osm_type': 'n'}}, 'website': 'https://www.pebblesinn.com/', 'contact': {'phone': 6880660, 'email': 'stay@pebblesinn.com'}, 'place_id': '51c6692d718945524059fa2813b80335e3bff00103f90105b359330100000092030b506562626c657320496e6e'}, 'geometry': {'type': 'Point', 'coordinates': [73.0865138, -0.6002214999400899]}}]}
# hithadhoo - nearest hotel: Pebbles Inn
# Response for adamstown: Status 200
# {'type': 'FeatureCollection', 'features': []}
# adamstown - nearest hotel: No hotel found
# Response for yellowknife: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'The Explorer Hotel', 'country': 'Canada', 'country_code': 'ca', 'state': 'Northwest Territories', 'county': 'North Slave Region', 'city': 'Yellowknife', 'postcode': 'X1A 3Y3', 'district': 'Capital Area', 'suburb': 'Downtown', 'street': 'Yellowknife Access Road', 'lon': -114.37279349003931, 'lat': 62.45765875, 'state_code': 'NT', 'formatted': 'The Explorer Hotel, Yellowknife Access Road, Yellowknife, NT X1A 3Y3, Canada', 'address_line1': 'The Explorer Hotel', 'address_line2': 'Yellowknife Access Road, Yellowknife, NT X1A 3Y3, Canada', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details.building'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'The Explorer Hotel', 'osm_id': 104226432, 'tourism': 'hotel', 'building': 'yes', 'osm_type': 'w', 'building:levels': 8}}, 'building': {'levels': 8}, 'place_id': '515cf839d9db975cc059eee0dc8f943a4f40f00102f901805e360600000000920312546865204578706c6f72657220486f74656c'}, 'geometry': {'type': 'Point', 'coordinates': [-114.37279349003933, 62.457658751345534]}}]}
# yellowknife - nearest hotel: The Explorer Hotel
# Response for avarua: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Natura Inano Villa', 'country': 'Cook Islands', 'country_code': 'ck', 'state': 'Rarotonga', 'city': 'Takitumu', 'village': 'Vaimaanga', 'street': 'Ara Metua', 'lon': -159.78408639999998, 'lat': -21.2619754, 'formatted': 'Natura Inano Villa, Ara Metua, Takitumu, Cook Islands', 'address_line1': 'Natura Inano Villa', 'address_line2': 'Ara Metua, Takitumu, Cook Islands', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'internet_access'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.facilities', 'details.payment'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Natura Inano Villa', 'brand': 'Natura Properties', 'email': 'info@islanderhotel.co.ck', 'phone': 29925, 'rooms': 3, 'stars': 3, 'osm_id': 391492126, 'smoking': 'no', 'tourism': 'hotel', 'website': 'https://www.booking.com/hotel/ck/natura-pandanus-villa.en-gb.html', 'building': 'hotel', 'operator': 'Natura Properties Limited', 'osm_type': 'w', 'description': 'Secluded, private and quiet 3-BM Holiday Villa walking distance to Vaimaanga Beach. Large holiday home perfect for groups and families.', 'payment:cash': 'yes', 'payment:visa': 'yes', 'internet_access': 'wlan', 'payment:mastercard': 'yes', 'internet_access:fee': 'yes'}}, 'website': 'https://www.booking.com/hotel/ck/natura-pandanus-villa.en-gb.html', 'brand': 'Natura Properties', 'operator': 'Natura Properties Limited', 'description': 'Secluded, private and quiet 3-BM Holiday Villa walking distance to Vaimaanga Beach. Large holiday home perfect for groups and families.', 'contact': {'phone': 29925, 'email': 'info@islanderhotel.co.ck'}, 'facilities': {'internet_access': True, 'smoking': False}, 'payment_options': {'cash': True, 'visa': True, 'mastercard': True}, 'accommodation': {'stars': 3, 'rooms': 3}, 'building': {'type': 'hotel'}, 'place_id': '51a0a75c3c17f963c059f48ee0d1104335c0f00102f9011eb25517000000009203124e617475726120496e616e6f2056696c6c61'}, 'geometry': {'type': 'Point', 'coordinates': [-159.78408639999998, -21.261975400279837]}}]}
# avarua - nearest hotel: Natura Inano Villa
# Response for kirakira: Status 200
# {'type': 'FeatureCollection', 'features': []}
# kirakira - nearest hotel: No hotel found
# Response for olonkinbyen: Status 200
# {'type': 'FeatureCollection', 'features': []}
# olonkinbyen - nearest hotel: No hotel found
# Response for okahao: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Oshikuku Town Lodge', 'country': 'Namibia', 'country_code': 'na', 'state': 'Omusati', 'city': 'Oshikuku', 'hamlet': 'Elalangali', 'postcode': '16003', 'street': 'D3611', 'lon': 15.44445020398381, 'lat': -17.641334399999998, 'state_code': 'OS', 'formatted': 'Oshikuku Town Lodge, D3611, Oshikuku 16003, Namibia', 'address_line1': 'Oshikuku Town Lodge', 'address_line2': 'D3611, Oshikuku 16003, Namibia', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Oshikuku Town Lodge', 'osm_id': 976295913, 'tourism': 'hotel', 'website': 'https://oshikukutownlodge.com.na', 'osm_type': 'w', 'addr:city': 'Oshikuku'}}, 'website': 'https://oshikukutownlodge.com.na', 'place_id': '513c9f25fa8ee32e405956d7c37d2ea431c0f00102f901e917313a000000009203134f7368696b756b7520546f776e204c6f646765'}, 'geometry': {'type': 'Point', 'coordinates': [15.444450203983813, -17.641334400475294]}}]}
# okahao - nearest hotel: Oshikuku Town Lodge
# Response for ushuaia: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Arakur', 'country': 'Argentina', 'country_code': 'ar', 'state': 'Tierra del Fuego Province', 'county': 'Departamento Ushuaia', 'city': 'Ushuaia', 'postcode': '9490', 'district': 'Ushuaia', 'suburb': 'Ruta 3', 'street': 'Camino Arakur', 'lon': -68.2600731708209, 'lat': -54.783791199999996, 'formatted': 'Camino Arakur, Ruta 3, 9490 Ushuaia, Argentina', 'address_line1': 'Camino Arakur', 'address_line2': 'Ruta 3, 9490 Ushuaia, Argentina', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.accommodation', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Arakur', 'phone': '+54 (2901) 44 2900', 'stars': 5, 'osm_id': 290283405, 'tourism': 'hotel', 'website': 'https://arakur.com/', 'building': 'hotel', 'osm_type': 'w'}}, 'website': 'https://arakur.com/', 'contact': {'phone': '+54 (2901) 44 2900'}, 'accommodation': {'stars': 5}, 'building': {'type': 'hotel'}, 'place_id': '5189cff009a51051c05924b61f4553644bc0f00102f9018d5f4d11000000009203064172616b7572'}, 'geometry': {'type': 'Point', 'coordinates': [-68.26007317082089, -54.783791199192166]}}]}
# ushuaia - nearest hotel: Arakur
# Response for port alfred: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Historic Pig and Whistle Inn', 'country': 'South Africa', 'country_code': 'za', 'state': 'Eastern Cape', 'county': 'Sarah Baartman District Municipality', 'city': 'Ndlambe Local Municipality', 'village': 'Bathurst', 'postcode': '6166', 'suburb': 'Ndlambe Ward 5', 'street': 'Kowie Road', 'housenumber': '268', 'lon': 26.8241715, 'lat': -33.5036721, 'state_code': 'EC', 'formatted': 'Historic Pig and Whistle Inn, 268 Kowie Road, Ndlambe Ward 5, Ndlambe Local Municipality, 6166, South Africa', 'address_line1': 'Historic Pig and Whistle Inn', 'address_line2': '268 Kowie Road, Ndlambe Ward 5, Ndlambe Local Municipality, 6166, South Africa', 'categories': ['accommodation', 'accommodation.hotel', 'internet_access', 'internet_access.for_customers'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Historic Pig and Whistle Inn', 'email': 'info@pigandwhistle.co.za', 'phone': '+27 46 6250673', 'rooms': 10, 'osm_id': 6080319954, 'amenity': 'pub;restaurant', 'smoking': 'outside', 'tourism': 'hotel', 'website': 'http://www.pigandwhistle.co.za/', 'osm_type': 'n', 'addr:city': 'Bathurst', 'start_date': 1832, 'addr:street': 'Kowie Road', 'addr:postcode': 6166, 'opening_hours': 'Mo-Su 08:00-23:00', 'internet_access': 'wlan', 'addr:housenumber': 268, 'internet_access:fee': 'customers'}}, 'website': 'http://www.pigandwhistle.co.za/', 'opening_hours': 'Mo-Su 08:00-23:00', 'contact': {'phone': '+27 46 6250673', 'email': 'info@pigandwhistle.co.za'}, 'facilities': {'internet_access': True, 'smoking': True}, 'accommodation': {'rooms': 10}, 'place_id': '5196cb46e7fcd23a4059dedacd5378c040c0f00103f901d2516a6a0100000092031c486973746f7269632050696720616e642057686973746c6520496e6e'}, 'geometry': {'type': 'Point', 'coordinates': [26.8241715, -33.503672099604714]}}]}
# port alfred - nearest hotel: Historic Pig and Whistle Inn
# Response for ribeira grande: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Hotel do Canal', 'country': 'Portugal', 'country_code': 'pt', 'city': 'Horta', 'postcode': '9900-026', 'district': 'Horta (Angústias)', 'suburb': 'Matriz', 'street': 'Largo Doutor Manuel de Arriaga', 'lon': -28.626799606345706, 'lat': 38.528397350000006, 'formatted': 'Hotel do Canal, Largo Doutor Manuel de Arriaga, 9900-026 Horta, Portugal', 'address_line1': 'Hotel do Canal', 'address_line2': 'Largo Doutor Manuel de Arriaga, 9900-026 Horta, Portugal', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Hotel do Canal', 'email': 'reservas.grupos@bhc.pt', 'phone': '+351 292 202120', 'stars': 4, 'osm_id': -17075236, 'landuse': 'commercial', 'name:pt': 'Hotel do Canal', 'tourism': 'hotel', 'website': 'https://www.bensaudehotels.com/en/hoteldocanal', 'osm_type': 'r', 'wikidata': 'Q111408376', 'addr:city': 'Horta (Angústias)', 'addr:street': 'Largo Dr. Manuel Arriaga', 'addr:country': 'PT', 'addr:postcode': '9900-026', 'name:etymology': 'Canal do Faial', 'name:etymology:wikidata': 'Q5429639', 'name:etymology:wikipedia': 'pt:Canal do Faial'}}, 'website': 'https://www.bensaudehotels.com/en/hoteldocanal', 'name_international': {'pt': 'Hotel do Canal'}, 'contact': {'phone': '+351 292 202120', 'email': 'reservas.grupos@bhc.pt'}, 'wiki_and_media': {'wikidata': 'Q111408376'}, 'accommodation': {'stars': 4}, 'place_id': '51846662f075a03cc05923e53c86a2434340f00101f901248c04010000000092030e486f74656c20646f2043616e616c'}, 'geometry': {'type': 'Point', 'coordinates': [-28.6267996063457, 38.528397350057524]}}]}
# ribeira grande - nearest hotel: Hotel do Canal
# Response for albany: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'DoubleTree', 'ref': 'SCHNTDT', 'country': 'United States', 'country_code': 'us', 'state': 'New York', 'county': 'Schenectady', 'city': 'City of Schenectady', 'postcode': '12308', 'district': 'Downtown', 'street': 'Nott Terrace', 'housenumber': '100', 'lon': -73.93606662730744, 'lat': 42.81255805, 'state_code': 'NY', 'formatted': 'DoubleTree, 100 Nott Terrace, City of Schenectady, NY 12308, United States of America', 'address_line1': 'DoubleTree', 'address_line2': '100 Nott Terrace, City of Schenectady, NY 12308, United States of America', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'ref': 'SCHNTDT', 'name': 'DoubleTree', 'brand': 'DoubleTree', 'phone': '+1 518-393-4141', 'branch': 'Hotel Schenectady', 'osm_id': -12540789, 'tourism': 'hotel', 'website': 'https://www.hilton.com/en/hotels/schntdt-doubletree-schenectady/', 'building': 'yes', 'osm_type': 'r', 'addr:city': 'Schenectady', 'addr:state': 'NY', 'addr:street': 'Nott Terrace', 'addr:country': 'US', 'addr:postcode': 12308, 'official_name': 'DoubleTree by Hilton', 'brand:wikidata': 'Q2504643', 'addr:housenumber': 100}}, 'website': 'https://www.hilton.com/en/hotels/schntdt-doubletree-schenectady/', 'brand': 'DoubleTree', 'brand_details': {'wikidata': 'Q2504643'}, 'branch': 'Hotel Schenectady', 'name_other': {'official_name': 'DoubleTree by Hilton'}, 'contact': {'phone': '+1 518-393-4141'}, 'place_id': '5166caff83e87b52c059e890f6e601684540f00101f901755bbf000000000092030a446f75626c6554726565'}, 'geometry': {'type': 'Point', 'coordinates': [-73.93606662730744, 42.81255805053098]}}]}
# albany - nearest hotel: DoubleTree
# Response for whitehorse: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Airport Chalet', 'country': 'Canada', 'country_code': 'ca', 'state': 'Yukon', 'city': 'Whitehorse', 'postcode': 'Y1A 3H3', 'district': 'Hillcrest', 'street': 'Alaska Highway', 'housenumber': '91634', 'lon': -135.0828257686332, 'lat': 60.714919050000006, 'state_code': 'YT', 'formatted': 'Airport Chalet, 91634 Alaska Highway, Whitehorse, YT Y1A 3H3, Canada', 'address_line1': 'Airport Chalet', 'address_line2': '91634 Alaska Highway, Whitehorse, YT Y1A 3H3, Canada', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'building.commercial'], 'details': ['details', 'details.accommodation', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'bar': 'yes', 'fax': '+1 867 667 2173', 'name': 'Airport Chalet', 'email': 'reservations@airportchalet.com', 'phone': '+1 866 668 2166', 'osm_id': 158988963, 'tourism': 'hotel', 'website': 'https://www.airportchalet.com/', 'building': 'commercial', 'osm_type': 'w', 'addr:city': 'Whitehorse', 'addr:street': 'Alaska Highway', 'reservation': 'yes', 'addr:province': 'YT', 'addr:housenumber': 91634}}, 'website': 'https://www.airportchalet.com/', 'contact': {'phone': '+1 866 668 2166', 'email': 'reservations@airportchalet.com', 'fax': '+1 867 667 2173'}, 'accommodation': {'reservation': 'required'}, 'building': {'type': 'commercial'}, 'place_id': '5176f13982a6e260c059ec42ad77825b4e40f00102f901a3fa79090000000092030e416972706f7274204368616c6574'}, 'geometry': {'type': 'Point', 'coordinates': [-135.0828257686332, 60.71491905174284]}}]}
# whitehorse - nearest hotel: Airport Chalet
# Response for thunder bay: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Comfort Inn', 'country': 'Canada', 'country_code': 'ca', 'state': 'Ontario', 'state_district': 'Northwestern Ontario', 'county': 'Thunder Bay District', 'city': 'Thunder Bay', 'postcode': 'P7E 6V6', 'street': 'Arthur Street West', 'housenumber': '660', 'lon': -89.29809129972159, 'lat': 48.380326249999996, 'state_code': 'ON', 'formatted': 'Comfort Inn, 660 Arthur Street West, Thunder Bay, ON P7E 6V6, Canada', 'address_line1': 'Comfort Inn', 'address_line2': '660 Arthur Street West, Thunder Bay, ON P7E 6V6, Canada', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Comfort Inn', 'brand': 'Comfort Inn', 'phone': '+1-807-475-3155', 'osm_id': 373023988, 'tourism': 'hotel', 'website': 'http://www.comfortinn.com/hotel-thunder_bay-canada-CN307', 'building': 'yes', 'osm_type': 'w', 'addr:street': 'Arthur Street West', 'brand:wikidata': 'Q113152349', 'brand:wikipedia': 'en:Choice Hotels', 'addr:housenumber': 660}}, 'website': 'http://www.comfortinn.com/hotel-thunder_bay-canada-CN307', 'brand': 'Comfort Inn', 'brand_details': {'wikidata': 'Q113152349', 'wikipedia': 'en:Choice Hotels'}, 'contact': {'phone': '+1-807-475-3155'}, 'place_id': '51b0e187ed135356c059d672d287ae304840f00102f901f4e43b160000000092030b436f6d666f727420496e6e'}, 'geometry': {'type': 'Point', 'coordinates': [-89.29809129972159, 48.380326249845595]}}]}
# thunder bay - nearest hotel: Comfort Inn
# Response for buka: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Отель «Инди-Анна»', 'country': 'Uzbekistan', 'country_code': 'uz', 'county': 'Yangi hayot district', 'city': 'Tashkent', 'postcode': '100000', 'suburb': 'Sergeli', 'street': 'Chinar Street', 'lon': 69.225664, 'lat': 41.2038608, 'formatted': 'Отель «Инди-Анна», Chinar Street, Tashkent, Uzbekistan, 100000', 'address_line1': 'Отель «Инди-Анна»', 'address_line2': 'Chinar Street, Tashkent, Uzbekistan, 100000', 'categories': ['accommodation', 'accommodation.hotel', 'internet_access'], 'details': ['details', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Отель «Инди-Анна»', 'phone': 2002007, 'osm_id': 5476109522, 'tourism': 'hotel', 'website': 'https://xn--c1acbqimbegavd6ftc.uz/index.php?dir=indi_butik', 'osm_type': 'n', 'addr:street': 'Чинар улица', 'opening_hours': '24/7', 'internet_access': 'wlan'}}, 'website': 'https://xn--c1acbqimbegavd6ftc.uz/index.php?dir=indi_butik', 'opening_hours': '24/7', 'contact': {'phone': 2002007}, 'facilities': {'internet_access': True}, 'place_id': '519cf86a47714e5140599b5b571c189a4440f00103f901d2cc664601000000920320d09ed182d0b5d0bbd18c20c2abd098d0bdd0b4d0b82dd090d0bdd0bdd0b0c2bb'}, 'geometry': {'type': 'Point', 'coordinates': [69.225664, 41.20386080041427]}}]}
# buka - nearest hotel: Отель «Инди-Анна»
# Response for grytviken: Status 200
# {'type': 'FeatureCollection', 'features': []}
# grytviken - nearest hotel: No hotel found
# Response for jalai nur: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': '鑫百合宾馆 (Xinbaihe Hotel)', 'country': 'China', 'country_code': 'cn', 'state': 'Inner Mongolia', 'city': "Zhalainuo'er", 'suburb': '第四街道', 'street': '健康路', 'lon': 117.6880911, 'lat': 49.4670158, 'formatted': '鑫百合宾馆 (Xinbaihe Hotel), 健康路, 第四街道, Inner Mongolia, China', 'address_line1': '鑫百合宾馆 (Xinbaihe Hotel)', 'address_line2': '健康路, 第四街道, Inner Mongolia, China', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': '鑫百合宾馆 (Xinbaihe Hotel)', 'phone': '+86 470 651 9797', 'osm_id': 4952557061, 'tourism': 'hotel', 'osm_type': 'n'}}, 'contact': {'phone': '+86 470 651 9797'}, 'place_id': '51cbca40af096c5d405967f3782cc7bb4840f00103f9010506322701000000920320e991abe799bee59088e5aebee9a686202858696e626169686520486f74656c29'}, 'geometry': {'type': 'Point', 'coordinates': [117.6880911, 49.467015799577716]}}]}
# jalai nur - nearest hotel: 鑫百合宾馆 (Xinbaihe Hotel)
# Response for puerto ayora: Status 200
# ...
# morondava - nearest hotel: Hôtel ROVASOA
# Response for coron: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Sea Dive Resort', 'country': 'Philippines', 'country_code': 'ph', 'region': 'Mimaropa', 'state': 'Palawan', 'city': 'Coron', 'village': 'Poblacion 1', 'postcode': '5316', 'street': 'Don Pedro Street', 'lon': 120.20169295360952, 'lat': 11.997647350000001, 'formatted': 'Sea Dive Resort, Don Pedro Street, Coron, 5316 Palawan, Philippines', 'address_line1': 'Sea Dive Resort', 'address_line2': 'Don Pedro Street, Coron, 5316 Palawan, Philippines', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'internet_access'], 'details': ['details', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Sea Dive Resort', 'phone': 918, 'osm_id': 245910844, 'tourism': 'hotel', 'website': 'www.seadiveresort.com', 'building': 'stilt_house', 'osm_type': 'w', 'addr:town': 'Coron', 'addr:street': 'Don Pedro St', 'internet_access': 'wlan', 'internet_access:fee': 'yes'}}, 'website': 'www.seadiveresort.com', 'contact': {'phone': 918}, 'facilities': {'internet_access': True}, 'building': {'type': 'stilt_house'}, 'place_id': '518ae58f89e80c5e40599ac626a2cbfe2740f00102f9013c4da80e0000000092030f5365612044697665205265736f7274'}, 'geometry': {'type': 'Point', 'coordinates': [120.20169295360952, 11.997647349580166]}}]}
# coron - nearest hotel: Sea Dive Resort
# Response for metlili chaamba: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'نزل الطاسيلي', 'country': 'Algeria', 'country_code': 'dz', 'state': 'Ghardaia', 'county': 'Ghardaia District', 'city': 'Ghardaia', 'postcode': '47000', 'district': 'Khettala', 'suburb': 'Theniet El Makhzene', 'street': 'شارع 1 نوفمبر', 'lon': 3.6842467, 'lat': 32.4782536, 'formatted': 'نزل الطاسيلي, شارع 1 نوفمبر, 47000 Ghardaia, Algeria', 'address_line1': 'نزل الطاسيلي', 'address_line2': 'شارع 1 نوفمبر, 47000 Ghardaia, Algeria', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'نزل الطاسيلي', 'phone': '029837321', 'osm_id': 4349692492, 'name:ar': 'نزل الطاسيلي', 'name:fr': 'Hôtel Tassili', 'tourism': 'hotel', 'osm_type': 'n', 'addr:city': 'غرداية', 'addr:street': 'شارع 1 نوفمبر', 'addr:city:ar': 'غرداية', 'addr:postcode': 47000, 'opening_hours': 'Mo-Su 06:00-23:00', 'addr:street:ar': 'شارع 1 نوفمبر'}}, 'opening_hours': 'Mo-Su 06:00-23:00', 'name_international': {'ar': 'نزل الطاسيلي', 'fr': 'Hôtel Tassili'}, 'contact': {'phone': '029837321'}, 'place_id': '51d92a775556790d4059deb9f869373d4040f00103f9014c0a430301000000920317d986d8b2d98420d8a7d984d8b7d8a7d8b3d98ad984d98a'}, 'geometry': {'type': 'Point', 'coordinates': [3.6842466999999997, 32.47825359959437]}}]}
# metlili chaamba - nearest hotel: نزل الطاسيلي
# Response for ghadamis: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'فندق ونزريك', 'country': 'Libya', 'country_code': 'ly', 'state': 'Nalut', 'city': 'Ghadames', 'street': 'Ghadames-Algerian Libyan border', 'lon': 9.4913335, 'lat': 30.1141089, 'formatted': 'Winzric Hotel -Ghadamis, Ghadames-Algerian Libyan border, Ghadames, Libya', 'address_line1': 'Winzric Hotel -Ghadamis', 'address_line2': 'Ghadames-Algerian Libyan border, Ghadames, Libya', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'فندق ونزريك', 'osm_id': 5264317823, 'name:ar': 'فندق ونزريك-غدامس', 'name:en': 'Winzric Hotel -Ghadamis', 'tourism': 'hotel', 'osm_type': 'n', 'addr:street': 'غدامس-الحدود الليبيه الجزائريه'}}, 'name_international': {'ar': 'فندق ونزريك-غدامس', 'en': 'Winzric Hotel -Ghadamis'}, 'place_id': '51c3db831090fb2240597e85a83d361d3e40f00103f9017f1dc73901000000920315d981d986d8afd98220d988d986d8b2d8b1d98ad983'}, 'geometry': {'type': 'Point', 'coordinates': [9.491333500000001, 30.114108899729665]}}]}
# ghadamis - nearest hotel: فندق ونزريك
# Response for champerico: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Mazari II', 'country': 'Mexico', 'country_code': 'mx', 'state': 'Chiapas', 'county': 'Suchiate', 'city': 'Ciudad Hidalgo', 'postcode': '30840', 'street': 'Entrada Jaritas-Ciudad Hidalgo', 'lon': -92.15591945132903, 'lat': 14.6722085, 'state_code': 'CHP', 'formatted': 'Mazari II, Entrada Jaritas-Ciudad Hidalgo, 30840 Ciudad Hidalgo, CHP, Mexico', 'address_line1': 'Mazari II', 'address_line2': 'Entrada Jaritas-Ciudad Hidalgo, 30840 Ciudad Hidalgo, CHP, Mexico', 'categories': ['accommodation', 'accommodation.hotel', 'catering', 'catering.restaurant'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Mazari II', 'email': 'hotel_plazamazari@hotmail.com', 'phone': '(962)698-1185', 'osm_id': 302351368, 'amenity': 'restaurant', 'tourism': 'hotel', 'website': 'hpmazari.hostei.com', 'operator': 'HOTEL PLAZA MAZARI S.A. DE C.V.', 'osm_type': 'w'}}, 'website': 'hpmazari.hostei.com', 'operator': 'HOTEL PLAZA MAZARI S.A. DE C.V.', 'contact': {'phone': '(962)698-1185', 'email': 'hotel_plazamazari@hotmail.com'}, 'place_id': '512e119495fa0957c059b10e66b62b582d40f00102f90108840512000000009203094d617a617269204949'}, 'geometry': {'type': 'Point', 'coordinates': [-92.15591945132903, 14.672208499868562]}}]}
# champerico - nearest hotel: Mazari II
# Response for umuarama: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Ibis Styles', 'country': 'Brazil', 'country_code': 'br', 'region': 'South Region', 'state': 'Paraná', 'state_district': 'Região Geográfica Intermediária de Maringá', 'county': 'Região Metropolitana de Umuarama', 'city': 'Umuarama', 'municipality': 'Região Geográfica Imediata de Umuarama', 'postcode': '87502-000', 'suburb': 'Parque Residencial Interlagos', 'street': 'Rua Leonildo Stecca', 'lon': -53.2834973058045, 'lat': -23.7546727, 'state_code': 'PR', 'formatted': 'Ibis Styles, Rua Leonildo Stecca, Parque Residencial Interlagos, Umuarama - PR, 87502-000, Brazil', 'address_line1': 'Ibis Styles', 'address_line2': 'Rua Leonildo Stecca, Parque Residencial Interlagos, Umuarama - PR, 87502-000, Brazil', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation'], 'details': ['details', 'details.building'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Ibis Styles', 'brand': 'Ibis Styles', 'osm_id': 436036311, 'tourism': 'hotel', 'building': 'yes', 'osm_type': 'w', 'brand:wikidata': 'Q3147425', 'brand:wikipedia': 'en:Ibis Styles', 'building:levels': 5}}, 'brand': 'Ibis Styles', 'brand_details': {'wikidata': 'Q3147425', 'wikipedia': 'en:Ibis Styles'}, 'building': {'levels': 5}, 'place_id': '519c77c4a349a44ac059e683e53a32c137c0f00102f901d762fd190000000092030b49626973205374796c6573'}, 'geometry': {'type': 'Point', 'coordinates': [-53.2834973058045, -23.7546726999607]}}]}
# umuarama - nearest hotel: Ibis Styles
# Response for basoda: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Krishna Hotel', 'country': 'India', 'country_code': 'in', 'state': 'Madhya Pradesh', 'state_district': 'Raisen District', 'county': 'Raisen Tahsil', 'city': 'Sanchi', 'postcode': '464661', 'district': 'Sanchi', 'street': 'Vidisha Road', 'lon': 77.7387209, 'lat': 23.4865191, 'state_code': 'MP', 'formatted': 'Krishna Hotel, Vidisha Road, Sanchi, Sanchi - 464661, Madhya Pradesh, India', 'address_line1': 'Krishna Hotel', 'address_line2': 'Vidisha Road, Sanchi, Sanchi - 464661, Madhya Pradesh, India', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details.accommodation', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Krishna Hotel', 'phone': '07482-266610', 'stars': 1, 'osm_id': 1124758438, 'tourism': 'hotel', 'osm_type': 'n', 'wheelchair': 'no', 'internet_access': 'no'}}, 'contact': {'phone': '07482-266610'}, 'facilities': {'internet_access': False, 'wheelchair': False}, 'place_id': '51c9970634476f5340597def08848c7c3740f00103f901a6730a430000000092030d4b726973686e6120486f74656c'}, 'geometry': {'type': 'Point', 'coordinates': [77.73872089999999, 23.48651910036232]}}]}
# basoda - nearest hotel: Krishna Hotel
# Response for urangan: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Susan River Homestead Adventure Resort', 'country': 'Australia', 'country_code': 'au', 'state': 'Queensland', 'city': 'Hervey Bay', 'municipality': 'Fraser Coast Regional', 'postcode': '4655', 'district': 'Susan River', 'street': 'Maryborough Hervey Bay Road', 'housenumber': '1946', 'lon': 152.7616273, 'lat': -25.4245735, 'state_code': 'QLD', 'formatted': 'Susan River Homestead Adventure Resort, 1946 Maryborough Hervey Bay Road, Hervey Bay QLD 4655, Australia', 'address_line1': 'Susan River Homestead Adventure Resort', 'address_line2': '1946 Maryborough Hervey Bay Road, Hervey Bay QLD 4655, Australia', 'categories': ['accommodation', 'accommodation.hotel', 'wheelchair', 'wheelchair.yes'], 'details': ['details', 'details.contact', 'details.facilities'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Susan River Homestead Adventure Resort', 'phone': '+61 7 4121 6846', 'osm_id': 3160458360, 'tourism': 'hotel', 'website': 'https://susanriver.com/', 'osm_type': 'n', 'addr:city': 'Hervey Bay', 'wheelchair': 'yes', 'addr:street': 'Maryborough-Hervey Bay Road', 'addr:postcode': 4655, 'addr:housenumber': 1946, 'toilets:wheelchair': 'yes'}}, 'website': 'https://susanriver.com/', 'contact': {'phone': '+61 7 4121 6846'}, 'facilities': {'wheelchair': True, 'toilets': True}, 'place_id': '51b42737405f18634059c60950d9b06c39c0f00103f90178c460bc00000000920326537573616e20526976657220486f6d65737465616420416476656e74757265205265736f7274'}, 'geometry': {'type': 'Point', 'coordinates': [152.7616273, -25.424573499718257]}}]}
# urangan - nearest hotel: Susan River Homestead Adventure Resort
# Response for ketou: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': "Hôtel Étoile d'or", 'country': 'Benin', 'country_code': 'bj', 'state': 'Plateau Department', 'county': 'Sakété', 'city': 'Pobè', 'hamlet': 'Hègô', 'street': 'RN 3', 'lon': 2.659237, 'lat': 6.9767237, 'formatted': "Hôtel Étoile d'or, RN 3, Pobè, Benin", 'address_line1': "Hôtel Étoile d'or", 'address_line2': 'RN 3, Pobè, Benin', 'categories': ['accommodation', 'accommodation.hotel'], 'details': ['details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': "Hôtel Étoile d'or", 'phone': 67592828, 'osm_id': 5749225673, 'tourism': 'hotel', 'osm_type': 'n'}}, 'contact': {'phone': 67592828}, 'place_id': '5156815a0c1e46054059c5b4e8412ae81b40f00103f901c938ae560100000092031348c3b474656c20c389746f696c652064276f72'}, 'geometry': {'type': 'Point', 'coordinates': [2.659237, 6.976723699405913]}}]}
# ketou - nearest hotel: Hôtel Étoile d'or
# Response for saint-pierre: Status 200
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Relais des Cimes', 'country': 'France', 'country_code': 'fr', 'state': 'Réunion', 'city': 'Hell Bourg', 'municipality': 'Saint-Benoît', 'postcode': '97433', 'street': 'Rue Amiral Lacaze', 'lon': 55.518596734465405, 'lat': -21.06626165, 'state_code': 'RE', 'state_COG': '04', 'formatted': 'Relais des Cimes, Rue Amiral Lacaze, 97433 Hell Bourg, France', 'address_line1': 'Relais des Cimes', 'address_line2': 'Rue Amiral Lacaze, 97433 Hell Bourg, France', 'categories': ['accommodation', 'accommodation.hotel', 'building', 'building.accommodation', 'internet_access', 'internet_access.free'], 'details': ['details', 'details.accommodation', 'details.contact', 'details.facilities', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Relais des Cimes', 'email': 'info@relaisdescimes.com', 'phone': '+262 47 81 58', 'stars': 2, 'osm_id': 67034677, 'tourism': 'hotel', 'website': 'https://www.relaisdescimes.com/', 'building': 'yes', 'osm_type': 'w', 'wikidata': 'Q3424009', 'internet_access': 'wlan', 'wikimedia_commons': 'Category:Relais des Cimes', 'internet_access:fee': 'no'}}, 'website': 'https://www.relaisdescimes.com/', 'contact': {'phone': '+262 47 81 58', 'email': 'info@relaisdescimes.com'}, 'facilities': {'internet_access': True}, 'wiki_and_media': {'wikidata': 'Q3424009', 'wikimedia_commons': 'Category:Relais des Cimes'}, 'accommodation': {'stars': 2}, 'place_id': '51b02bb76061c24b40594a040586f61035c0f00102f90135defe030000000092031052656c616973206465732043696d6573'}, 'geometry': {'type': 'Point', 'coordinates': [55.518596734465405, -21.06626165029983]}}]}
# saint-pierre - nearest hotel: Relais des Cimes
#             City Country      Lat       Lng  Humidity  \
# 0  blackmans bay      AU -43.0167  147.3167        60
# 1        stanley      GB  54.8680   -1.6985        89
# 2          tiksi      RU  71.6872  128.8694        99
# 3     queenstown      ZA -31.8976   26.8753        92
# 4     concepcion      CL -36.8270  -73.0498        67
#
#                       Hotel Name
# 0  Hotel Grand Chancellor Hobart
# 1     Hilton Newcastle Gateshead
# 2                        Арктика
# 3                   Queens Hotel
# 4      Wyndham Concepción Pettra

# %%
#Rechecking the data in hotel df
hotel_df.head()
# Out:
#             City Country      Lat       Lng  Humidity  \
# 0  blackmans bay      AU -43.0167  147.3167        60
# 1        stanley      GB  54.8680   -1.6985        89
# 2          tiksi      RU  71.6872  128.8694        99
# 3     queenstown      ZA -31.8976   26.8753        92
# 4     concepcion      CL -36.8270  -73.0498        67
#
#                       Hotel Name
# 0  Hotel Grand Chancellor Hobart
# 1     Hilton Newcastle Gateshead
# 2                        Арктика
# 3                   Queens Hotel
# 4      Wyndham Concepción Pettra

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    size="Humidity",
    scale=1,
    color="City",
    tiles="OSM",
    frame_width=700,
    frame_height=500,
    hover_cols=["Hotel Name", "Country"],  # Including columns for the hover
   # tools=[hover_tool]  # Use the custom hover tool
)
 
# Displaying the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
