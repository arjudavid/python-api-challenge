# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in d:\anaconda\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in d:\anaconda\lib\site-packages (from citipy) (0.16)

# %%
# Writting down Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Importing the OpenWeatherMap API key
from api_keys import weather_api_key

# Importing citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Printing the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Setting the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Defining an empty list to fetch the weather data for each city
city_data = []

# Printing to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Creating counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Grouping cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Creating endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=imperial"# YOUR CODE HERE

    # Logging the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Running an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | ulsteinvik
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | iskateley
# Processing Record 5 of Set 1 | west island
# Processing Record 6 of Set 1 | ad darb
# Processing Record 7 of Set 1 | nantucket
# Processing Record 8 of Set 1 | utrik
# Processing Record 9 of Set 1 | yarega
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | gornozavodsk
# Processing Record 12 of Set 1 | vernon
# Processing Record 13 of Set 1 | flin flon
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | grytviken
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | tura
# Processing Record 18 of Set 1 | tazovsky
# Processing Record 19 of Set 1 | wagar
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | adamstown
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | talnakh
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | edinburgh of the seven seas
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | port mathurin
# Processing Record 30 of Set 1 | salinopolis
# Processing Record 31 of Set 1 | rio grande
# Processing Record 32 of Set 1 | ash shafa
# Processing Record 33 of Set 1 | enewetak
# Processing Record 34 of Set 1 | kencong
# Processing Record 35 of Set 1 | kiama
# Processing Record 36 of Set 1 | leava
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | lokken
# City not found. Skipping...
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | chonchi
# Processing Record 41 of Set 1 | igreja
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | stanley
# Processing Record 44 of Set 1 | chibougamau
# Processing Record 45 of Set 1 | minot
# Processing Record 46 of Set 1 | atafu village
# Processing Record 47 of Set 1 | pimentel
# Processing Record 48 of Set 1 | yarovoye
# Processing Record 49 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 50 of Set 1 | gamboma
# Processing Record 35 of Set 4 | axim
# Processing Record 36 of Set 4 | invercargill
# Processing Record 37 of Set 4 | barra de santo antonio
# Processing Record 38 of Set 4 | chernyshevskiy
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | mar del plata
# Processing Record 41 of Set 4 | irati
# Processing Record 42 of Set 4 | san luis de la loma
# Processing Record 43 of Set 4 | sabzevar
# Processing Record 44 of Set 4 | lihue
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | choma
# Processing Record 47 of Set 4 | dolbeau-mistassini
# Processing Record 48 of Set 4 | flying fish cove
# Processing Record 49 of Set 4 | necochea
# Processing Record 0 of Set 5 | ilulissat
# Processing Record 1 of Set 5 | klyuchi
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 5 | fuqing
# Processing Record 5 of Set 5 | tazacorte
# Processing Record 6 of Set 5 | jabal os saraj
# Processing Record 7 of Set 5 | tofol
# Processing Record 8 of Set 5 | la gi
# Processing Record 9 of Set 5 | kirakira
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | north bellport
# Processing Record 12 of Set 5 | piti village
# Processing Record 13 of Set 5 | ulanhot
# Processing Record 14 of Set 5 | gwadar
# Processing Record 15 of Set 5 | turan
# Processing Record 16 of Set 5 | indramayu
# Processing Record 17 of Set 5 | mananara
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | kerman
# Processing Record 20 of Set 5 | kolwezi
# Processing Record 21 of Set 5 | segorbe
# Processing Record 22 of Set 5 | tracy
# Processing Record 23 of Set 5 | dingwall
# Processing Record 24 of Set 5 | kenai
# Processing Record 25 of Set 5 | kingston
# Processing Record 26 of Set 5 | aasiaat
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | elgin
# Processing Record 29 of Set 5 | taldykorgan
# Processing Record 30 of Set 5 | korotchaevo
# City not found. Skipping...
# Processing Record 31 of Set 5 | fale old settlement
# Processing Record 32 of Set 5 | yatou
# Processing Record 33 of Set 5 | hollola
# Processing Record 34 of Set 5 | vuktyl
# Processing Record 35 of Set 5 | kovdor
# Processing Record 36 of Set 5 | igarka
# Processing Record 37 of Set 5 | jamestown
# Processing Record 38 of Set 5 | pangkalanbuun
# Processing Record 39 of Set 5 | punta cana
# Processing Record 40 of Set 5 | codrington
# Processing Record 41 of Set 5 | jalai nur
# Processing Record 42 of Set 5 | gandajika
# Processing Record 43 of Set 5 | santa cecilia
# Processing Record 44 of Set 5 | rongelap
# Processing Record 45 of Set 5 | praia da vitoria
# Processing Record 46 of Set 5 | placido de castro
# Processing Record 47 of Set 5 | port elizabeth
# Processing Record 48 of Set 5 | crane
# Processing Record 49 of Set 5 | camapua
# Processing Record 0 of Set 6 | mabaruma
# Processing Record 1 of Set 6 | howard springs
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | farafangana
# Processing Record 4 of Set 6 | madison heights
# Processing Record 5 of Set 6 | terenozek
# Processing Record 6 of Set 6 | agat village
# Processing Record 7 of Set 6 | mejit
# Processing Record 8 of Set 6 | hamilton
# Processing Record 9 of Set 6 | pahlgam
# Processing Record 10 of Set 6 | tarinkot
# Processing Record 11 of Set 6 | jianguang
# Processing Record 12 of Set 6 | nadym
# Processing Record 13 of Set 6 | naze
# Processing Record 14 of Set 6 | horqueta
# Processing Record 15 of Set 6 | nyurba
# Processing Record 16 of Set 6 | chui
# Processing Record 17 of Set 6 | malango
# Processing Record 18 of Set 6 | kokologo
# Processing Record 19 of Set 6 | shohimardon
# Processing Record 20 of Set 6 | cox's bazar
# Processing Record 21 of Set 6 | la ronge
# Processing Record 22 of Set 6 | menongue
# Processing Record 23 of Set 6 | rocha
# Processing Record 24 of Set 6 | arkhangel'sk
# Processing Record 25 of Set 6 | severo-yeniseyskiy
# Processing Record 26 of Set 6 | santa ana
# Processing Record 27 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 28 of Set 6 | moroto
# Processing Record 29 of Set 6 | cockburn town
# Processing Record 30 of Set 6 | as sulayyil
# Processing Record 31 of Set 6 | nizhnesortymskiy
# Processing Record 32 of Set 6 | lodja
# Processing Record 33 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 34 of Set 6 | palangkaraya
# Processing Record 35 of Set 6 | khabarovsk
# Processing Record 36 of Set 6 | remire-montjoly
# Processing Record 37 of Set 6 | olinda
# Processing Record 38 of Set 6 | cadale
# Processing Record 39 of Set 6 | musay'id
# City not found. Skipping...
# Processing Record 40 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 6 | ad dilam
# Processing Record 42 of Set 6 | puerto santa
# Processing Record 43 of Set 6 | zhangye
# Processing Record 44 of Set 6 | vertientes
# Processing Record 45 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 46 of Set 6 | bikenibeu village
# Processing Record 47 of Set 6 | pachino
# Processing Record 48 of Set 6 | callao
# Processing Record 49 of Set 6 | colby
# Processing Record 0 of Set 7 | orapa
# Processing Record 1 of Set 7 | whiteville
# Processing Record 2 of Set 7 | mountain home
# Processing Record 3 of Set 7 | cassilandia
# Processing Record 4 of Set 7 | namest nad oslavou
# Processing Record 5 of Set 7 | belo sur tsiribihina
# Processing Record 6 of Set 7 | fredericton
# Processing Record 7 of Set 7 | soufriere
# Processing Record 8 of Set 7 | natal
# Processing Record 9 of Set 7 | sol'-iletsk
# Processing Record 10 of Set 7 | nuuk
# Processing Record 11 of Set 7 | tralee
# Processing Record 12 of Set 7 | miri
# Processing Record 13 of Set 7 | akhmet'a
# Processing Record 14 of Set 7 | gwaram
# Processing Record 15 of Set 7 | baglung
# Processing Record 16 of Set 7 | mongo
# Processing Record 17 of Set 7 | slave lake
# Processing Record 18 of Set 7 | mil'kovo
# Processing Record 19 of Set 7 | calipatria
# Processing Record 5 of Set 10 | kodinsk
# Processing Record 6 of Set 10 | twon-brass
# Processing Record 7 of Set 10 | yanbu
# Processing Record 8 of Set 10 | richards bay
# Processing Record 9 of Set 10 | abadan
# Processing Record 10 of Set 10 | gao
# Processing Record 11 of Set 10 | mao
# Processing Record 12 of Set 10 | farmville
# Processing Record 13 of Set 10 | bodo
# Processing Record 14 of Set 10 | inhambane
# Processing Record 15 of Set 10 | port hedland
# Processing Record 16 of Set 10 | hami
# Processing Record 17 of Set 10 | pasni
# Processing Record 18 of Set 10 | bridgewater
# Processing Record 19 of Set 10 | springs
# Processing Record 20 of Set 10 | polyarnyy
# Processing Record 21 of Set 10 | miyako
# Processing Record 22 of Set 10 | saint-philippe
# Processing Record 23 of Set 10 | thunder bay
# Processing Record 24 of Set 10 | mochudi
# Processing Record 25 of Set 10 | tegueste
# Processing Record 26 of Set 10 | johi
# Processing Record 27 of Set 10 | puerto baquerizo moreno
# Processing Record 28 of Set 10 | hartselle
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | al-`ula
# City not found. Skipping...
# Processing Record 31 of Set 10 | mermoz boabab
# Processing Record 32 of Set 10 | bardai
# Processing Record 33 of Set 10 | do'stlik shahri
# City not found. Skipping...
# Processing Record 34 of Set 10 | parabel'
# Processing Record 35 of Set 10 | novotroitskaya
# Processing Record 36 of Set 10 | ixtapa
# Processing Record 37 of Set 10 | burang
# Processing Record 38 of Set 10 | laojunmiao
# Processing Record 39 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 40 of Set 10 | yilan
# Processing Record 41 of Set 10 | suai
# City not found. Skipping...
# Processing Record 42 of Set 10 | chok chai
# Processing Record 43 of Set 10 | turpan
# Processing Record 44 of Set 10 | wysokie mazowieckie
# Processing Record 45 of Set 10 | north battleford
# Processing Record 46 of Set 10 | kisaran
# Processing Record 47 of Set 10 | songea
# Processing Record 48 of Set 10 | vigan
# Processing Record 49 of Set 10 | opuwo
# Processing Record 0 of Set 11 | babu
# Processing Record 1 of Set 11 | new richmond
# Processing Record 2 of Set 11 | sinjar
# Processing Record 3 of Set 11 | khovd
# Processing Record 4 of Set 11 | segezha
# Processing Record 5 of Set 11 | conduaga
# Processing Record 6 of Set 11 | mournies
# Processing Record 7 of Set 11 | kabinda
# Processing Record 8 of Set 11 | new norfolk
# Processing Record 9 of Set 11 | pacasmayo
# Processing Record 10 of Set 11 | ulaangom
# Processing Record 11 of Set 11 | viedma
# Processing Record 12 of Set 11 | kangding
# Processing Record 13 of Set 11 | mukah
# City not found. Skipping...
# Processing Record 14 of Set 11 | pavlovsk
# Processing Record 15 of Set 11 | ust'-ilimsk
# Processing Record 16 of Set 11 | znamenskoye
# Processing Record 17 of Set 11 | plesetsk
# Processing Record 18 of Set 11 | kolpashevo
# Processing Record 19 of Set 11 | yaren
# Processing Record 20 of Set 11 | conception bay south
# Processing Record 21 of Set 11 | kavaratti
# Processing Record 22 of Set 11 | vodnyy
# Processing Record 23 of Set 11 | ad dabbah
# Processing Record 24 of Set 11 | kudahuvadhoo
# Processing Record 25 of Set 11 | lorengau
# Processing Record 26 of Set 11 | mirny
# Processing Record 27 of Set 11 | pauini
# Processing Record 28 of Set 11 | kill devil hills
# Processing Record 29 of Set 11 | coahuayana de hidalgo
# Processing Record 30 of Set 11 | porto seguro
# Processing Record 31 of Set 11 | petrolina
# Processing Record 32 of Set 11 | mahanoro
# Processing Record 33 of Set 11 | shahrud
# Processing Record 34 of Set 11 | princeville
# Processing Record 35 of Set 11 | kalmunai
# Processing Record 36 of Set 11 | machico
# Processing Record 37 of Set 11 | la'ie
# Processing Record 38 of Set 11 | tawau
# Processing Record 39 of Set 11 | copiapo
# Processing Record 40 of Set 11 | mwene-ditu
# Processing Record 41 of Set 11 | ugoofaaru
# Processing Record 42 of Set 11 | kawambwa
# Processing Record 43 of Set 11 | baiti
# Processing Record 44 of Set 11 | bisbee
# Processing Record 45 of Set 11 | rastede
# Processing Record 46 of Set 11 | gewane
# Processing Record 47 of Set 11 | buka
# Processing Record 48 of Set 11 | hachinohe
# Processing Record 49 of Set 11 | peterborough
# Processing Record 0 of Set 12 | virovitica
# Processing Record 1 of Set 12 | perelyub
# Processing Record 2 of Set 12 | wad az zaki
# Processing Record 3 of Set 12 | broken hill
# Processing Record 4 of Set 12 | linxia chengguanzhen
# Processing Record 5 of Set 12 | rabaul
# Processing Record 6 of Set 12 | yangambi
# Processing Record 7 of Set 12 | sheki
# Processing Record 8 of Set 12 | ceeldheer
# Processing Record 9 of Set 12 | valenca do piaui
# Processing Record 10 of Set 12 | phan rang-thap cham
# Processing Record 11 of Set 12 | kapsan-up
# Processing Record 12 of Set 12 | schoningen
# Processing Record 13 of Set 12 | skovorodino
# Processing Record 14 of Set 12 | radhakund
# Processing Record 15 of Set 12 | jambi city
# Processing Record 16 of Set 12 | jingmen
# Processing Record 17 of Set 12 | amga
# Processing Record 18 of Set 12 | ust'-barguzin
# Processing Record 19 of Set 12 | whitecourt
# Processing Record 20 of Set 12 | al jumum
# Processing Record 21 of Set 12 | port saint john's
# Processing Record 22 of Set 12 | key largo
# Processing Record 23 of Set 12 | posto fiscal rolim de moura
# Processing Record 24 of Set 12 | fort mcmurray
# Processing Record 25 of Set 12 | labasa
# Processing Record 26 of Set 12 | wanning
# Processing Record 27 of Set 12 | sao lourenco do oeste
# Processing Record 28 of Set 12 | barclayville
# Processing Record 29 of Set 12 | bamboo flat
# Processing Record 30 of Set 12 | floro
# Processing Record 31 of Set 12 | alice springs
# Processing Record 32 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 12 | laguna
# Processing Record 34 of Set 12 | priekuli
# City not found. Skipping...
# Processing Record 35 of Set 12 | sajir
# Processing Record 36 of Set 12 | monrovia
# Processing Record 37 of Set 12 | vel'sk
# Processing Record 38 of Set 12 | haimen
# Processing Record 39 of Set 12 | banda aceh
# Processing Record 40 of Set 12 | portland
# Processing Record 41 of Set 12 | hutang
# Processing Record 42 of Set 12 | walvis bay
# Processing Record 43 of Set 12 | faya-largeau
# Processing Record 44 of Set 12 | tshikapa
# Processing Record 45 of Set 12 | sainte-adresse
# Processing Record 46 of Set 12 | gunnison
# Processing Record 47 of Set 12 | krasnapollye
# Processing Record 48 of Set 12 | alto barinas
# Processing Record 49 of Set 12 | eyl
# Processing Record 0 of Set 13 | korkut
# Processing Record 1 of Set 13 | slivnitsa
# Processing Record 2 of Set 13 | ravar
# Processing Record 3 of Set 13 | piton saint-leu
# Processing Record 4 of Set 13 | childress
# Processing Record 5 of Set 13 | qamdo
# Processing Record 6 of Set 13 | shingu
# Processing Record 7 of Set 13 | santa maria
# Processing Record 8 of Set 13 | norrtalje
# Processing Record 9 of Set 13 | isna
# Processing Record 10 of Set 13 | robertsport
# Processing Record 11 of Set 13 | dakhla
# Processing Record 12 of Set 13 | wuzhou
# Processing Record 13 of Set 13 | papao
# Processing Record 14 of Set 13 | zeulenroda
# Processing Record 15 of Set 13 | chipinge
# Processing Record 16 of Set 13 | okha
# Processing Record 17 of Set 13 | vizinga
# Processing Record 18 of Set 13 | abidjan
# Processing Record 19 of Set 13 | los alamos
# Processing Record 20 of Set 13 | borujen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Displaying sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0             albany  42.6001 -73.9662     56.05        61         100
# 1         ulsteinvik  62.3432   5.8487     44.73        93          92
# 2  port-aux-francais -49.3500  70.2167     40.93        94         100
# 3          iskateley  67.6803  53.1512     15.28        99          89
# 4        west island -12.1568  96.8225     80.58        83         100
#
#    Wind Speed Country        Date
# 0        1.99      US  1731374352
# 1        8.14      NO  1731374652
# 2       16.20      TF  1731374653
# 3        5.28      RU  1731374654
# 4       11.50      CC  1731374655

# %%
# Exporting the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Reading saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Displaying sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   albany  42.6001 -73.9662     56.05        61         100
# 1               ulsteinvik  62.3432   5.8487     44.73        93          92
# 2        port-aux-francais -49.3500  70.2167     40.93        94         100
# 3                iskateley  67.6803  53.1512     15.28        99          89
# 4              west island -12.1568  96.8225     80.58        83         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.99      US  1731374352
# 1              8.14      NO  1731374652
# 2             16.20      TF  1731374653
# 3              5.28      RU  1731374654
# 4             11.50      CC  1731374655

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Building a scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (F) (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Building the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity % (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Building the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Building the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Defining a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, output_file):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate regression line values
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r-", label=f"y={slope:.2f}x + {intercept:.2f}")
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Displaying the r-squared value
    plt.text(0.5, 0.05, f"y = {slope:.2f}x + {intercept:.2f}", transform=plt.gca().transAxes, color= "red", fontsize=16, fontweight='bold')
    
    
    # Save the plot
    plt.savefig(output_file)
    
    # Show the plot
    #print(f"y= {slope:.2f}x + {intercept:.2f}")
    print(f"The r^2-value is: {rvalue**2:.6f}")
    plt.show()

# %%
# Creating a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Displaying sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            albany  42.6001 -73.9662     56.05        61         100
# 1        ulsteinvik  62.3432   5.8487     44.73        93          92
# 3         iskateley  67.6803  53.1512     15.28        99          89
# 5           ad darb  17.7229  42.2526     82.96        69           7
# 6         nantucket  41.2835 -70.0995     57.31        94           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.99      US  1731374352
# 1              8.14      NO  1731374652
# 3              5.28      RU  1731374654
# 5              2.06      SA  1731374657
# 6             10.36      US  1731374494

# %%
# Creating a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Displaying sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2        port-aux-francais -49.3500   70.2167     40.93        94         100
# 4              west island -12.1568   96.8225     80.58        83         100
# 13                waitangi -43.9535 -176.5597     56.82        68          51
# 14               grytviken -54.2811  -36.5092     31.37        91          92
# 19                    lebu -37.6167  -73.6500     52.90        73          73
#
#          Wind Speed Country        Date
# City_ID
# 2             16.20      TF  1731374653
# 4             11.50      CC  1731374655
# 13             5.99      NZ  1731374666
# 14            11.32      GS  1731374668
# 19            16.55      CL  1731374674

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Defining the x and y values for the linear regression (Latitude vs Max Temperature)

plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temperature (F)", "Linear Regression: Latitude vs Max Temperature (Northern Hemisphere)", "Fig_1")
# Out:
# The r^2-value is: 0.745923

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Max Temperature (F)", "Linear Regression: Latitude vs Max Temperature (Southern Hemisphere)", "Fig_2")
# Out:
# The r^2-value is: 0.444781

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemipshere we can see that the more latitude there is the lower the temperature it will be; meanwhile in the Southern Hempishere is the opposite, the more latitude there is the greater the temperature there will be.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity (%)", "Linear Regression: Latitude vs Humidity (Northern Hemisphere)", "Fig_3")
# Out:
# The r^2-value is: 0.115943

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity (%)", "Linear Regression: Latitude vs Humidity (Southern Hemisphere)", "Fig_4")
# Out:
# The r^2-value is: 0.030936

# %% [markdown]
# **Discussion about the linear relationship:** While the latitude may be different the Humidity remains almost the same in both the Northern and the Southern Hemisphers. The Humidity increases in both as the latitude increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", "Linear Regression: Latitude vs Cloudiness (Northern Hemisphere)", "Fig_5")
# Out:
# The r^2-value is: 0.083074

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", "Linear Regression: Latitude vs Cloudiness (Southern Hemisphere)", "Fig_6")
# Out:
# The r^2-value is: 0.002331

# %% [markdown]
# **Discussion about the linear relationship:** While the latitude may be different the Cloudiness remains almost the same in both the Northern and the Southern Hemisphers. The Cloudiness increases in both as the latitude increases, although in the Northrn Hemipshere tends to be a little bit more cloudy.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", "Linear Regression: Latitude vs Wind Speed (m/s) (Northern Hemisphere)", "Fig_7")
# Out:
# The r^2-value is: 0.016388

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", "Linear Regression: Latitude vs Wind Speed (m/s) (Southern Hemisphere)", "Fig_8")
# Out:
# The r^2-value is: 0.033287

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere the more Latitude there is the more windy it becomes. While in the Southern Hemipshere the more Latitude there is the wind starts to drop its speed.
