# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Collecting citipy
#   Downloading citipy-0.0.6.tar.gz (675 kB)
#      ---------------------------------------- 0.0/675.6 kB ? eta -:--:--
#       --------------------------------------- 10.2/675.6 kB ? eta -:--:--
#       --------------------------------------- 10.2/675.6 kB ? eta -:--:--
#      - ----------------------------------- 30.7/675.6 kB 217.9 kB/s eta 0:00:03
#      --- --------------------------------- 61.4/675.6 kB 328.2 kB/s eta 0:00:02
#      ---------- ------------------------- 194.6/675.6 kB 841.6 kB/s eta 0:00:01
#      ------------------------- ------------ 460.8/675.6 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 675.6/675.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting kdtree>=0.12 (from citipy)
#   Downloading kdtree-0.16-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Created wheel for citipy: filename=citipy-0.0.6-py3-none-any.whl size=675977 sha256=77ae05ec765aae7bff0b3bd548c9a0d1b828ee5706ef0b535b4f721e95f900c3
#   Stored in directory: c:\users\arjun\appdata\local\pip\cache\wheels\e9\27\5f\7defd70aaec29af33fe5e2110843e14dcfc44cba710a0dd957
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.6 kdtree-0.16

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 621

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}?q={city}&appid={weather_api_key}&units=imperial"# YOUR CODE HERE

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        response = requests.get(city_url)
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | blackmans bay
# Processing Record 2 of Set 1 | stanley
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | queenstown
# Processing Record 5 of Set 1 | concepcion
# Processing Record 6 of Set 1 | saipan
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | aasiaat
# Processing Record 9 of Set 1 | edinburgh of the seven seas
# Processing Record 10 of Set 1 | rio claro
# Processing Record 11 of Set 1 | ke-macina
# Processing Record 12 of Set 1 | udachny
# Processing Record 13 of Set 1 | vorgashor
# Processing Record 14 of Set 1 | acarau
# Processing Record 15 of Set 1 | horta
# Processing Record 16 of Set 1 | 'alaqahdari dishu
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | kirakira
# Processing Record 23 of Set 1 | olonkinbyen
# Processing Record 24 of Set 1 | cairns city
# City not found. Skipping...
# Processing Record 25 of Set 1 | okahao
# Processing Record 26 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | whitehorse
# Processing Record 32 of Set 1 | thunder bay
# Processing Record 33 of Set 1 | buka
# Processing Record 34 of Set 1 | grytviken
# Processing Record 35 of Set 1 | jalai nur
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | zeya
# Processing Record 38 of Set 1 | shingu
# Processing Record 39 of Set 1 | hawaiian paradise park
# Processing Record 40 of Set 1 | gonzalez
# Processing Record 41 of Set 1 | bayanhongor
# Processing Record 42 of Set 1 | aur
# Processing Record 43 of Set 1 | qaqortoq
# Processing Record 44 of Set 1 | tazovsky
# Processing Record 45 of Set 1 | titahari
# Processing Record 46 of Set 1 | puerto natales
# Processing Record 47 of Set 1 | atafu village
# Processing Record 48 of Set 1 | west island
# Processing Record 49 of Set 1 | susuman
# Processing Record 50 of Set 1 | waitangi
# Processing Record 0 of Set 2 | forest acres
# Processing Record 1 of Set 2 | constantia
# Processing Record 2 of Set 2 | hamilton
# Processing Record 3 of Set 2 | yaren
# Processing Record 4 of Set 2 | manuel ojinaga
# City not found. Skipping...
# Processing Record 5 of Set 2 | crucecita
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | lebu
# Processing Record 8 of Set 2 | oualidia
# City not found. Skipping...
# Processing Record 9 of Set 2 | kashgar
# Processing Record 10 of Set 2 | ust-nera
# Processing Record 11 of Set 2 | wailua homesteads
# Processing Record 12 of Set 2 | aripuana
# Processing Record 13 of Set 2 | isafjordur
# Processing Record 14 of Set 2 | xilin hot
# Processing Record 15 of Set 2 | melfort
# Processing Record 16 of Set 2 | papatowai
# Processing Record 17 of Set 2 | fale old settlement
# Processing Record 18 of Set 2 | marsh harbour
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | les anglais
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | weno
# Processing Record 23 of Set 2 | gueltat zemmour
# City not found. Skipping...
# Processing Record 24 of Set 2 | altai
# Processing Record 25 of Set 2 | malvern
# Processing Record 26 of Set 2 | margaret river
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | beyneu
# Processing Record 29 of Set 2 | novaya igirma
# Processing Record 30 of Set 2 | la passe
# Processing Record 31 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 32 of Set 2 | bilibino
# Processing Record 33 of Set 2 | ingeniero guillermo n. juarez
# Processing Record 34 of Set 2 | knyaze-volkonskoye
# Processing Record 35 of Set 2 | kayangel
# Processing Record 36 of Set 2 | uzgen
# Processing Record 37 of Set 2 | igarka
# Processing Record 38 of Set 2 | utrik
# Processing Record 39 of Set 2 | ravar
# Processing Record 40 of Set 2 | soto la marina
# Processing Record 41 of Set 2 | gadzhiyevo
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | akhty
# Processing Record 44 of Set 2 | van
# Processing Record 45 of Set 2 | bima
# Processing Record 13 of Set 4 | dryden
# Processing Record 14 of Set 4 | canavieiras
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | szombathely
# Processing Record 17 of Set 4 | nadi
# Processing Record 18 of Set 4 | muynoq
# Processing Record 19 of Set 4 | xacmaz
# Processing Record 20 of Set 4 | invercargill
# Processing Record 21 of Set 4 | berezovyy
# Processing Record 22 of Set 4 | kachug
# Processing Record 23 of Set 4 | howrah
# Processing Record 24 of Set 4 | krapivinskiy
# Processing Record 25 of Set 4 | kismayo
# Processing Record 26 of Set 4 | tolanaro
# Processing Record 27 of Set 4 | ponmana
# City not found. Skipping...
# Processing Record 28 of Set 4 | ballito
# Processing Record 29 of Set 4 | mejit
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | galle
# Processing Record 32 of Set 4 | truro
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | bredasdorp
# Processing Record 35 of Set 4 | holualoa
# Processing Record 36 of Set 4 | kampong chhnang
# Processing Record 37 of Set 4 | chegdomyn
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | gaspe
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | vilyuchinsk
# Processing Record 42 of Set 4 | krasnovishersk
# Processing Record 43 of Set 4 | miasskoye
# Processing Record 44 of Set 4 | grande prairie
# Processing Record 45 of Set 4 | tazacorte
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | kosan
# Processing Record 48 of Set 4 | san kamphaeng
# Processing Record 49 of Set 4 | rio grande
# Processing Record 0 of Set 5 | merizo village
# Processing Record 1 of Set 5 | sovetskaya gavan'
# Processing Record 2 of Set 5 | xai-xai
# Processing Record 3 of Set 5 | st. john's
# Processing Record 4 of Set 5 | labytnangi
# Processing Record 5 of Set 5 | hualien city
# Processing Record 6 of Set 5 | anadyr
# Processing Record 7 of Set 5 | college
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | afaahiti
# Processing Record 10 of Set 5 | bokoro
# Processing Record 11 of Set 5 | paradip garh
# Processing Record 12 of Set 5 | sann
# Processing Record 13 of Set 5 | tangalle
# Processing Record 14 of Set 5 | saquarema
# Processing Record 15 of Set 5 | paris
# Processing Record 16 of Set 5 | chibougamau
# Processing Record 17 of Set 5 | kolonia
# Processing Record 18 of Set 5 | lepsy
# Processing Record 19 of Set 5 | emerald
# Processing Record 20 of Set 5 | quellon
# Processing Record 21 of Set 5 | ouellah
# City not found. Skipping...
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | gemena
# Processing Record 24 of Set 5 | ghat
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | saudarkrokur
# Processing Record 27 of Set 5 | al jawf
# Processing Record 28 of Set 5 | nyagan
# Processing Record 29 of Set 5 | abraham's bay
# City not found. Skipping...
# Processing Record 30 of Set 5 | ambon
# Processing Record 31 of Set 5 | norman gardens
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | male
# Processing Record 34 of Set 5 | gasa
# Processing Record 35 of Set 5 | cuajinicuilapa
# Processing Record 36 of Set 5 | cheraw
# Processing Record 37 of Set 5 | braslaw
# Processing Record 38 of Set 5 | genhe
# Processing Record 39 of Set 5 | yuzhno-kurilsk
# Processing Record 40 of Set 5 | keflavik
# Processing Record 41 of Set 5 | ayacucho
# Processing Record 42 of Set 5 | vadso
# Processing Record 43 of Set 5 | anna regina
# Processing Record 44 of Set 5 | chinde
# Processing Record 45 of Set 5 | gornozavodsk
# Processing Record 46 of Set 5 | upata
# Processing Record 47 of Set 5 | illizi
# Processing Record 48 of Set 5 | torit
# Processing Record 49 of Set 5 | namdrik
# Processing Record 0 of Set 6 | paveh
# Processing Record 1 of Set 6 | midvagur
# Processing Record 2 of Set 6 | mbandaka
# Processing Record 3 of Set 6 | nikolayevsk-on-amure
# Processing Record 4 of Set 6 | polavaram
# Processing Record 5 of Set 6 | nemuro
# Processing Record 6 of Set 6 | cole harbour
# Processing Record 7 of Set 6 | lamu
# Processing Record 8 of Set 6 | kourou
# Processing Record 9 of Set 6 | sarangani
# Processing Record 10 of Set 6 | hermanus
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | foiano della chiana
# Processing Record 13 of Set 6 | manatutu
# City not found. Skipping...
# Processing Record 14 of Set 6 | dwarka
# Processing Record 15 of Set 6 | villa gesell
# Processing Record 16 of Set 6 | molde
# Processing Record 17 of Set 6 | nar'yan-mar
# Processing Record 18 of Set 6 | kpandae
# Processing Record 19 of Set 6 | kailua-kona
# Processing Record 20 of Set 6 | newborough
# Processing Record 21 of Set 6 | pitkyaranta
# Processing Record 22 of Set 6 | fisterra
# Processing Record 23 of Set 6 | tingo maria
# Processing Record 24 of Set 6 | tofol
# Processing Record 25 of Set 6 | panaba
# Processing Record 26 of Set 6 | marquette
# Processing Record 27 of Set 6 | broken hill
# Processing Record 28 of Set 6 | christchurch
# Processing Record 29 of Set 6 | shizunai-furukawacho
# Processing Record 30 of Set 6 | gamba
# Processing Record 31 of Set 6 | farim
# Processing Record 32 of Set 6 | embi
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | liupanshui
# City not found. Skipping...
# Processing Record 35 of Set 6 | tralee
# Processing Record 36 of Set 6 | benjamin constant
# Processing Record 37 of Set 6 | birzebbuga
# Processing Record 38 of Set 6 | saint-francois
# Processing Record 39 of Set 6 | leh
# Processing Record 40 of Set 6 | dudinka
# Processing Record 41 of Set 6 | majie
# Processing Record 42 of Set 6 | vaureal
# Processing Record 43 of Set 6 | lihue
# Processing Record 44 of Set 6 | coahuayana de hidalgo
# Processing Record 45 of Set 6 | jiujiang
# Processing Record 46 of Set 6 | vilhena
# Processing Record 47 of Set 6 | zaragoza
# Processing Record 48 of Set 6 | homer
# Processing Record 49 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 0 of Set 7 | conduaga
# Processing Record 42 of Set 9 | anacapri
# Processing Record 43 of Set 9 | gizo
# Processing Record 44 of Set 9 | east london
# Processing Record 45 of Set 9 | tukrah
# Processing Record 46 of Set 9 | ankazoabo
# Processing Record 47 of Set 9 | governor's harbour
# City not found. Skipping...
# Processing Record 48 of Set 9 | elliot lake
# Processing Record 49 of Set 9 | balakliya
# Processing Record 0 of Set 10 | boca suno
# Processing Record 1 of Set 10 | antsiranana
# Processing Record 2 of Set 10 | mount pearl
# Processing Record 3 of Set 10 | chu
# Processing Record 4 of Set 10 | kamyshevatskaya
# Processing Record 5 of Set 10 | cidade velha
# Processing Record 6 of Set 10 | kukmor
# Processing Record 7 of Set 10 | sola
# Processing Record 8 of Set 10 | calvinia
# Processing Record 9 of Set 10 | fauske
# Processing Record 10 of Set 10 | ruteng
# Processing Record 11 of Set 10 | vila franca do campo
# Processing Record 12 of Set 10 | kiunga
# Processing Record 13 of Set 10 | loango
# Processing Record 14 of Set 10 | globe
# City not found. Skipping...
# Processing Record 15 of Set 10 | fuglafjordur
# Processing Record 16 of Set 10 | vanimo
# Processing Record 17 of Set 10 | karasuyama
# Processing Record 18 of Set 10 | fontaine-les-dijon
# Processing Record 19 of Set 10 | harper
# Processing Record 20 of Set 10 | pohang
# Processing Record 21 of Set 10 | brokopondo
# Processing Record 22 of Set 10 | forster
# Processing Record 23 of Set 10 | shimoda
# Processing Record 24 of Set 10 | hobyo
# Processing Record 25 of Set 10 | santa maria
# Processing Record 26 of Set 10 | kargasok
# Processing Record 27 of Set 10 | kaffrine
# Processing Record 28 of Set 10 | saint-philippe
# Processing Record 29 of Set 10 | taro
# Processing Record 30 of Set 10 | tweed heads
# Processing Record 31 of Set 10 | tieli
# Processing Record 32 of Set 10 | nago
# Processing Record 33 of Set 10 | san luis de la loma
# Processing Record 34 of Set 10 | praia da vitoria
# Processing Record 35 of Set 10 | andovoranto
# Processing Record 36 of Set 10 | bela
# Processing Record 37 of Set 10 | eydhafushi
# Processing Record 38 of Set 10 | mogadishu
# Processing Record 39 of Set 10 | boundiali
# Processing Record 40 of Set 10 | sofifi
# Processing Record 41 of Set 10 | mugia
# Processing Record 42 of Set 10 | progreso
# Processing Record 43 of Set 10 | karratha
# Processing Record 44 of Set 10 | rongelap
# Processing Record 45 of Set 10 | keetmanshoop
# Processing Record 46 of Set 10 | revda
# Processing Record 47 of Set 10 | naracoorte
# Processing Record 48 of Set 10 | portage la prairie
# Processing Record 49 of Set 10 | venadillo
# Processing Record 0 of Set 11 | pailitas
# Processing Record 1 of Set 11 | ocean pointe
# City not found. Skipping...
# Processing Record 2 of Set 11 | minas
# Processing Record 3 of Set 11 | bikenibeu village
# Processing Record 4 of Set 11 | shetpe
# Processing Record 5 of Set 11 | kapa'a
# Processing Record 6 of Set 11 | rizhao
# Processing Record 7 of Set 11 | jaru
# Processing Record 8 of Set 11 | alice springs
# Processing Record 9 of Set 11 | nosy varika
# Processing Record 10 of Set 11 | krasnohrad
# Processing Record 11 of Set 11 | dergaon
# Processing Record 12 of Set 11 | acayuca
# Processing Record 13 of Set 11 | shahrak-e pabedana
# City not found. Skipping...
# Processing Record 14 of Set 11 | nyala
# Processing Record 15 of Set 11 | maracai
# Processing Record 16 of Set 11 | galesong
# Processing Record 17 of Set 11 | hami
# Processing Record 18 of Set 11 | kampene
# Processing Record 19 of Set 11 | chipinge
# Processing Record 20 of Set 11 | caleta olivia
# Processing Record 21 of Set 11 | guachochi
# City not found. Skipping...
# Processing Record 22 of Set 11 | grand baie
# Processing Record 23 of Set 11 | bubaque
# Processing Record 24 of Set 11 | omutinskiy
# Processing Record 25 of Set 11 | sodo
# Processing Record 26 of Set 11 | beas de segura
# Processing Record 27 of Set 11 | narvik
# Processing Record 28 of Set 11 | pacasmayo
# Processing Record 29 of Set 11 | duong dong
# Processing Record 30 of Set 11 | yilan
# Processing Record 31 of Set 11 | juneau
# Processing Record 32 of Set 11 | larroque
# Processing Record 33 of Set 11 | bridgewater
# Processing Record 34 of Set 11 | lucapa
# Processing Record 35 of Set 11 | kaka
# Processing Record 36 of Set 11 | yekaterinoslavka
# Processing Record 37 of Set 11 | nizhneangarsk
# Processing Record 38 of Set 11 | nouadhibou
# Processing Record 39 of Set 11 | salinopolis
# Processing Record 40 of Set 11 | el campello
# Processing Record 41 of Set 11 | cuenca
# Processing Record 42 of Set 11 | nova vicosa
# Processing Record 43 of Set 11 | smithers
# Processing Record 44 of Set 11 | hastings
# Processing Record 45 of Set 11 | laguna
# Processing Record 46 of Set 11 | ekibastuz
# Processing Record 47 of Set 11 | anabar
# City not found. Skipping...
# Processing Record 48 of Set 11 | naze
# Processing Record 49 of Set 11 | bathsheba
# Processing Record 0 of Set 12 | maiwut
# City not found. Skipping...
# Processing Record 1 of Set 12 | newman
# Processing Record 2 of Set 12 | vilyuysk
# Processing Record 3 of Set 12 | plettenberg bay
# Processing Record 4 of Set 12 | aykhal
# Processing Record 5 of Set 12 | bereznik
# Processing Record 6 of Set 12 | tarapur
# Processing Record 7 of Set 12 | puerto lempira
# Processing Record 8 of Set 12 | mukalla
# Processing Record 9 of Set 12 | kingston
# Processing Record 10 of Set 12 | pisco
# Processing Record 11 of Set 12 | sarmiento
# Processing Record 12 of Set 12 | dawei
# Processing Record 13 of Set 12 | laayoune plage
# City not found. Skipping...
# Processing Record 14 of Set 12 | dalandzadgad
# Processing Record 15 of Set 12 | isangel
# Processing Record 16 of Set 12 | brookings
# Processing Record 17 of Set 12 | luanda
# Processing Record 18 of Set 12 | carutapera
# Processing Record 19 of Set 12 | coxen hole
# Processing Record 20 of Set 12 | mato verde
# Processing Record 21 of Set 12 | tynda
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | cedeira
# Processing Record 24 of Set 12 | namibe
# Processing Record 25 of Set 12 | cooma
# Processing Record 26 of Set 12 | santa cruz del sur
# Processing Record 27 of Set 12 | novodvinsk
# Processing Record 28 of Set 12 | mersing
# Processing Record 29 of Set 12 | savanna-la-mar
# Processing Record 30 of Set 12 | igrim
# Processing Record 31 of Set 12 | ola
# Processing Record 32 of Set 12 | palu
# Processing Record 33 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 34 of Set 12 | markaz-e hukumat-e darweshan
# Processing Record 35 of Set 12 | bargara
# City not found. Skipping...
# Processing Record 36 of Set 12 | kuching
# Processing Record 37 of Set 12 | chunar
# Processing Record 38 of Set 12 | ebon
# Processing Record 39 of Set 12 | kirby muxloe
# Processing Record 40 of Set 12 | carora
# Processing Record 41 of Set 12 | januaria
# Processing Record 42 of Set 12 | esplanada
# Processing Record 43 of Set 12 | faya-largeau
# Processing Record 44 of Set 12 | taulaga
# Processing Record 45 of Set 12 | magadan
# Processing Record 46 of Set 12 | save
# Processing Record 47 of Set 12 | oarai
# Processing Record 48 of Set 12 | la ronge
# Processing Record 49 of Set 12 | saurimo
# Processing Record 0 of Set 13 | guanambi
# Processing Record 1 of Set 13 | warrnambool
# Processing Record 2 of Set 13 | nkhata bay
# Processing Record 3 of Set 13 | bu'aale
# Processing Record 4 of Set 13 | argo
# Processing Record 5 of Set 13 | saint-jean-de-monts
# Processing Record 6 of Set 13 | happy valley-goose bay
# Processing Record 7 of Set 13 | pedernales
# Processing Record 8 of Set 13 | hohhot
# Processing Record 9 of Set 13 | poxoreo
# Processing Record 10 of Set 13 | morondava
# Processing Record 11 of Set 13 | coron
# Processing Record 12 of Set 13 | metlili chaamba
# Processing Record 13 of Set 13 | ghadamis
# Processing Record 14 of Set 13 | champerico
# Processing Record 15 of Set 13 | umuarama
# Processing Record 16 of Set 13 | basoda
# Processing Record 17 of Set 13 | yangor
# City not found. Skipping...
# Processing Record 18 of Set 13 | urangan
# Processing Record 19 of Set 13 | ketou
# Processing Record 20 of Set 13 | saint-pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  blackmans bay -43.0167  147.3167     60.53        60           1
# 1        stanley  54.8680   -1.6985     45.18        89           0
# 2          tiksi  71.6872  128.8694     -0.51        99          86
# 3     queenstown -31.8976   26.8753     54.81        92         100
# 4     concepcion -36.8270  -73.0498     58.80        67          40
#
#    Wind Speed Country        Date
# 0        1.01      AU  1731280921
# 1       10.36      GB  1731280922
# 2        3.00      RU  1731280923
# 3        4.27      ZA  1731280924
# 4       10.36      CL  1731280918

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        blackmans bay -43.0167  147.3167     60.53        60           1
# 1              stanley  54.8680   -1.6985     45.18        89           0
# 2                tiksi  71.6872  128.8694     -0.51        99          86
# 3           queenstown -31.8976   26.8753     54.81        92         100
# 4           concepcion -36.8270  -73.0498     58.80        67          40
#
#          Wind Speed Country        Date
# City_ID
# 0              1.01      AU  1731280921
# 1             10.36      GB  1731280922
# 2              3.00      RU  1731280923
# 3              4.27      ZA  1731280924
# 4             10.36      CL  1731280918

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (F) (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity % (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (11-10-2024)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, output_file):
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate regression line values
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values, edgecolor="black", linewidths=1, marker="o", alpha=0.8)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r-", label=f"y={slope:.2f}x + {intercept:.2f}")
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Display the r-squared value
    #plt.text(0.5, 0.05, f"y = {slope:.2f}x + {intercept:.2f}", transform=plt.gca().transAxes, color= "red")
    
    
    # Save the plot
    plt.savefig(output_file)
    
    # Show the plot
    print(f"y= {slope:.2f}x + {intercept:.2f}")
    print(f"The r^2-value is: {rvalue**2:.6f}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             stanley  54.8680   -1.6985     45.18        89           0
# 2               tiksi  71.6872  128.8694     -0.51        99          86
# 5              saipan  15.1355  145.7010     88.50        81           0
# 6        longyearbyen  78.2186   15.6401     26.44        93          75
# 7             aasiaat  68.7098  -52.8699     13.26        99          90
#
#          Wind Speed Country        Date
# City_ID
# 1             10.36      GB  1731280922
# 2              3.00      RU  1731280923
# 5             12.66      MP  1731280927
# 6              3.44      SJ  1731280928
# 7              4.88      GL  1731280929

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <= 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                      blackmans bay -43.0167  147.3167     60.53        60
# 3                         queenstown -31.8976   26.8753     54.81        92
# 4                         concepcion -36.8270  -73.0498     58.80        67
# 8        edinburgh of the seven seas -37.0676  -12.3116     60.48        86
# 9                          rio claro -22.4114  -47.5614     70.75        69
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 1        1.01      AU  1731280921
# 3               100        4.27      ZA  1731280924
# 4                40       10.36      CL  1731280918
# 8               100       32.06      SH  1731280930
# 9                 1        8.23      BR  1731280932

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Define the x and y values for the linear regression (Latitude vs Max Temperature)

plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temperature (F)", "Linear Regression: Latitude vs Max Temperature (Northern Hemisphere)", "Fig_1")
# Out:
# y= -1.05x + 91.47
# The r^2-value is: 0.752230

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Max Temperature (F)", "Linear Regression: Latitude vs Max Temperature (Southern Hemisphere)", "Fig_2")
# Out:
# y= 0.55x + 82.17
# The r^2-value is: 0.482501

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemipshere we can see that the more latitude there is the lower the temperature it will be; meanwhile in the Southern Hempishere is the opposite, the more latitude there is the greater the temperature there will be.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity (%)", "Linear Regression: Latitude vs Humidity (Northern Hemisphere)", "Fig_3")
# Out:
# y= 0.16x + 70.21
# The r^2-value is: 0.030307

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity (%)", "Linear Regression: Latitude vs Humidity (Southern Hemisphere)", "Fig_4")
# Out:
# y= 0.25x + 79.09
# The r^2-value is: 0.042985

# %% [markdown]
# **Discussion about the linear relationship:** While the latitude may be different the Humidity remains almost the same in both the Northern and the Southern Hemisphers. The Humidity increases in both as the latitude increases.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", "Linear Regression: Latitude vs Cloudiness (Northern Hemisphere)", "Fig_5")
# Out:
# y= 0.36x + 41.17
# The r^2-value is: 0.035980

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", "Linear Regression: Latitude vs Cloudiness (Southern Hemisphere)", "Fig_6")
# Out:
# y= 0.31x + 67.41
# The r^2-value is: 0.016012

# %% [markdown]
# **Discussion about the linear relationship:** While the latitude may be different the Cloudiness remains almost the same in both the Northern and the Southern Hemisphers. The Cloudiness increases in both as the latitude increases, although in the Northrn Hemipshere tends to be a little bit more cloudy.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", "Linear Regression: Latitude vs Wind Speed (m/s) (Northern Hemisphere)", "Fig_7")
# Out:
# y= 0.05x + 5.75
# The r^2-value is: 0.026201

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", "Linear Regression: Latitude vs Wind Speed (m/s) (Southern Hemisphere)", "Fig_8")
# Out:
# y= -0.13x + 6.16
# The r^2-value is: 0.094824

# %% [markdown]
# **Discussion about the linear relationship:** In the Northern Hemisphere the more Latitude there is the more windy it becomes. While in the Southern Hemipshere the more Latitude there is the wind starts to drop its speed.
